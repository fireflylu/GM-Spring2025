# %% [markdown]
# # Neighborhood Computations

# %%
import numpy as np
# import igl
import meshplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import igl
#       3 import meshplot
#
# ModuleNotFoundError: No module named 'igl'

# %%
bunny_v, bunny_f = igl.read_triangle_mesh("data/bunny.off")
cube_v, cube_f = igl.read_triangle_mesh("data/cube.obj")
sphere_v, sphere_f = igl.read_triangle_mesh("data/sphere.obj")

# %%
meshplot.plot(bunny_v, bunny_f, shading={"wireframe": True})
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-0.016860…

# %%
meshplot.plot(cube_v, cube_f, shading={"wireframe": True})
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.0, 0.0,…

# %%
meshplot.plot(sphere_v, sphere_f, shading={"wireframe": True})
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.0, 0.0,…

# %% [markdown]
# ## Vertex-to-Face Relations

# %%
def VtF(V, F):
    l, n = igl.vertex_triangle_adjacency(F, V.size)

    for i in range(n.size):
        if n[i] >= l.size: break
        print(f"Vertex {i}:")

        s = "Faces: "
        al = []

        for j in range(n[i+1]-n[i]):
            al.append(l[n[i]+j])
        print(s + f"{al}")
            
    return

# %% [markdown]
# ## Vertex-to-Vertex Relations

# %%
def VtV(V):
    l = igl.adjacency_list(V)
    print(l)

    for i in range(len(l)):
        faces = []
        print(f"Vertex adjacent to vertex {i}:")
        for j in l[i]:
            faces.append(j)
        print(faces)
        
    return

# %%
# neighborhood relations

VtF(bunny_v, bunny_f)
print()
VtV(bunny_f)
# Out:
# Vertex 0:
# Faces: [849, 850, 912, 944, 945]
# Vertex 1:
# Faces: [738, 788, 1278, 1833]
# Vertex 2:
# Faces: [248, 2795, 2857, 2972, 3408]
# Vertex 3:
# Faces: [911, 912, 945, 960, 974, 991]
# Vertex 4:
# Faces: [971, 2977, 2984, 3012, 3013]
# Vertex 5:
# Faces: [1455, 1658, 1706, 2471, 4816, 4884]
# Vertex 6:
# Faces: [1906, 2443, 2506, 2518, 2526]
# Vertex 7:
# Faces: [5, 15, 103, 2576, 2697, 2799]
# Vertex 8:
# Faces: [55, 118, 144, 2711, 3005]
# Vertex 9:
# Faces: [2599, 2729, 2805, 2945, 3066]
# Vertex 10:
# Faces: [96, 941, 2736, 2773, 2803, 2832, 3164, 3165]
# Vertex 11:
# Faces: [13, 96, 1082, 1689, 2736, 3137, 3143]
# Vertex 12:
# Faces: [1689, 3137, 3816, 3911]
# Vertex 13:
# Faces: [1037, 1053, 1054, 1087, 1122, 1133, 1134]
# Vertex 14:
# Faces: [90, 107, 123, 139]
# Vertex 15:
# Faces: [1017, 1036, 1053, 1074, 1121, 1122]
# Vertex 16:
# Faces: [712, 713, 728, 737, 750, 1970, 2034]
# Vertex 17:
# Faces: [680, 713, 728, 3078]
# Vertex 18:
# Faces: [407, 515, 2113, 2114, 2246, 2335, 3402]
# Vertex 19:
# Faces: [99, 100, 164, 209, 884, 886, 984]
# Vertex 20:
# Faces: [409, 410, 411, 1540, 3177, 3178, 3237]
# Vertex 21:
# Faces: [410, 411, 476, 1318, 1432, 4921, 5709]
# Vertex 22:
# Faces: [2341, 2654, 2657, 3021, 3030, 3043]
# Vertex 23:
# Faces: [789, 1508, 2944, 3009, 3018, 3046]
# Vertex 24:
# Faces: [850, 851, 913, 931, 944]
# Vertex 25:
# Faces: [191, 217, 219, 1090, 1758, 6015, 6456]
# Vertex 26:
# Faces: [915, 1468, 1538, 1547, 1777, 3003]
# Vertex 27:
# Faces: [2816, 2829, 2830, 2858, 2869, 2962]
# Vertex 28:
# Faces: [2780, 2858, 2868, 2869, 4105, 4670]
# Vertex 29:
# Faces: [2573, 2679, 2742, 2777, 2781, 2928]
# Vertex 30:
# Faces: [622, 639, 657, 3121, 3139]
# Vertex 31:
# Faces: [217, 1040, 1041, 1643, 4181, 6456]
# Vertex 32:
# Faces: [2685, 2689, 2760, 2761, 4804]
# Vertex 33:
# Faces: [1301, 1312, 2559, 3513, 3567, 3625]
# Vertex 34:
# Faces: [9, 411, 413, 1540, 3181, 5709]
# Vertex 35:
# Faces: [681, 3167, 3247, 3849, 5153]
# Vertex 36:
# Faces: [190, 191, 235, 527, 785, 1090, 1542]
# Vertex 37:
# Faces: [190, 191, 216, 218, 219]
# Vertex 38:
# Faces: [216, 217, 219, 353, 1041, 1254]
# Vertex 39:
# Faces: [651, 653, 694, 1628, 1719]
# Vertex 40:
# Faces: [86, 247, 355, 792, 804, 2622]
# Vertex 41:
# Faces: [2675, 2677, 2684, 2685, 2761]
# Vertex 42:
# Faces: [76, 421, 617, 2609, 2616, 2621, 4692]
# Vertex 43:
# Faces: [657, 681, 682, 3121, 3247]
# Vertex 44:
# Faces: [681, 682, 3256, 3289, 3548, 3849]
# Vertex 45:
# Faces: [40, 2873, 3948, 3987, 5194, 6107]
# Vertex 46:
# Faces: [102, 900, 901, 2589, 3185]
# Vertex 47:
# Faces: [900, 902, 951, 1552, 3185]
# Vertex 48:
# Faces: [951, 965, 1025, 1061, 1552, 1625, 1656, 3433]
# Vertex 49:
# Faces: [1061, 1092, 1154, 1169, 1431, 1626, 1656]
# Vertex 50:
# Faces: [1154, 1155, 1169, 1191, 1192, 1193]
# Vertex 51:
# Faces: [235, 326, 338, 785, 1191, 1192]
# Vertex 52:
# Faces: [326, 509, 527, 785]
# Vertex 53:
# Faces: [494, 524, 580, 602, 1579, 2969]
# Vertex 54:
# Faces: [820, 897, 1183, 1185, 1186, 1203]
# Vertex 55:
# Faces: [969, 1177, 2190, 2718, 2853, 4029]
# Vertex 56:
# Faces: [89, 373, 448, 3181, 3476, 4921, 5709]
# Vertex 57:
# Faces: [448, 476, 874, 4921]
# Vertex 58:
# Faces: [476, 511, 553, 554, 874, 1318, 1972]
# Vertex 59:
# Faces: [900, 901, 918, 938, 951, 952, 965, 966]
# Vertex 60:
# Faces: [965, 966, 995, 1025, 1026]
# Vertex 61:
# Faces: [1025, 1026, 1061, 1062, 1092, 1093]
# Vertex 62:
# Faces: [188, 338, 438, 1192, 1193, 1194]
# Vertex 63:
# Faces: [189, 190, 218, 509, 527, 567]
# Vertex 64:
# Faces: [189, 216, 218, 353, 548, 693, 747]
# Vertex 65:
# Faces: [477, 511, 512, 1972]
# Vertex 66:
# Faces: [881, 882, 918, 919, 938]
# Vertex 67:
# Faces: [995, 997, 1026, 1027, 1062, 1063]
# Vertex 68:
# Faces: [1062, 1063, 1093, 1095]
# Vertex 69:
# Faces: [1092, 1093, 1094, 1095, 1126, 1154, 1155]
# Vertex 70:
# Faces: [1126, 1139, 1155, 1193, 1194]
# Vertex 71:
# Faces: [326, 338, 367, 438, 509, 567]
# Vertex 72:
# Faces: [284, 313, 548, 604, 693, 2070]
# Vertex 73:
# Faces: [149, 155, 156, 187]
# Vertex 74:
# Faces: [118, 1136, 1137, 1189, 2711]
# Vertex 75:
# Faces: [506, 916, 934, 2491, 4548, 6077]
# Vertex 76:
# Faces: [295, 526, 976, 1056, 1057]
# Vertex 77:
# Faces: [89, 448, 469, 477, 874, 1972, 4698]
# Vertex 78:
# Faces: [511, 512, 532, 554, 571, 572]
# Vertex 79:
# Faces: [571, 572, 587, 622, 623, 639]
# Vertex 80:
# Faces: [623, 639, 640, 657, 682, 695, 696, 3548]
# Vertex 81:
# Faces: [695, 696, 716, 753, 3096]
# Vertex 82:
# Faces: [919, 920, 921, 938, 952, 953]
# Vertex 83:
# Faces: [952, 953, 966, 967, 995, 996, 997]
# Vertex 84:
# Faces: [1027, 1046, 1063, 1079, 1094, 1095, 1096]
# Vertex 85:
# Faces: [1094, 1096, 1112, 1113, 1126, 1139, 1140]
# Vertex 86:
# Faces: [188, 221, 367, 417, 438, 528, 649]
# Vertex 87:
# Faces: [179, 189, 221, 367, 567, 747]
# Vertex 88:
# Faces: [179, 259, 313, 324, 693, 747]
# Vertex 89:
# Faces: [819, 916, 934, 1240, 1881, 6333, 6427]
# Vertex 90:
# Faces: [495, 506, 2587, 4548]
# Vertex 91:
# Faces: [532, 533, 572, 587, 2881]
# Vertex 92:
# Faces: [640, 641, 658, 683, 696, 716]
# Vertex 93:
# Faces: [2877, 2887, 2894, 2910, 2911, 2912, 2924]
# Vertex 94:
# Faces: [920, 921, 922, 923, 3135, 3321, 3489]
# Vertex 95:
# Faces: [920, 923, 953, 954, 967, 968]
# Vertex 96:
# Faces: [967, 968, 996, 999]
# Vertex 97:
# Faces: [996, 997, 998, 999, 1027, 1028, 1046]
# Vertex 98:
# Faces: [259, 284, 313, 1042, 1794]
# Vertex 99:
# Faces: [490, 495, 506, 819, 916, 2359]
# Vertex 100:
# Faces: [180, 282, 490, 495, 1077, 1241, 2587]
# Vertex 101:
# Faces: [21, 56, 115, 127, 173, 844]
# Vertex 102:
# Faces: [1060, 1863, 1983, 2142, 2427]
# Vertex 103:
# Faces: [279, 638, 680, 2699, 2813, 3078]
# Vertex 104:
# Faces: [2768, 2867, 2938, 3021, 3030]
# Vertex 105:
# Faces: [954, 968, 998, 999, 1000, 3147]
# Vertex 106:
# Faces: [1028, 1046, 1064, 1079, 1097, 3488, 3614]
# Vertex 107:
# Faces: [1079, 1096, 1097, 1113]
# Vertex 108:
# Faces: [188, 417, 1139, 1140, 1156, 1194, 1205]
# Vertex 109:
# Faces: [179, 221, 324, 528, 875, 935]
# Vertex 110:
# Faces: [62, 588, 1450, 2686, 2769, 2947, 2954]
# Vertex 111:
# Faces: [793, 824, 862, 3090, 3478, 3572]
# Vertex 112:
# Faces: [1112, 1140, 1156, 1157, 3216]
# Vertex 113:
# Faces: [237, 275, 417, 649, 1205]
# Vertex 114:
# Faces: [275, 404, 528, 649, 726, 875]
# Vertex 115:
# Faces: [72, 81, 82, 3296, 3305, 3426]
# Vertex 116:
# Faces: [72, 82, 106, 3245, 3253]
# Vertex 117:
# Faces: [245, 1797, 2081, 2549, 2825, 4753]
# Vertex 118:
# Faces: [924, 1359, 1423, 2584, 2922, 2929]
# Vertex 119:
# Faces: [862, 3090, 3146, 3292]
# Vertex 120:
# Faces: [237, 257, 275, 354, 404, 486, 1138]
# Vertex 121:
# Faces: [258, 259, 324, 786, 935, 1006, 1042]
# Vertex 122:
# Faces: [295, 383, 526, 950, 1644, 1695, 1931]
# Vertex 123:
# Faces: [408, 491, 1077, 1209, 1241]
# Vertex 124:
# Faces: [587, 608, 623, 640, 641, 2881, 3225]
# Vertex 125:
# Faces: [683, 716, 730, 753, 793, 3572]
# Vertex 126:
# Faces: [730, 731, 793, 794, 824]
# Vertex 127:
# Faces: [1864, 4082, 4119, 4120, 4142, 6568]
# Vertex 128:
# Faces: [237, 1138, 1156, 1157, 1170, 1205, 1206]
# Vertex 129:
# Faces: [214, 255, 258, 442, 726, 875, 935]
# Vertex 130:
# Faces: [214, 241, 258, 786, 2517]
# Vertex 131:
# Faces: [86, 327, 792, 964, 2047, 2738]
# Vertex 132:
# Faces: [705, 706, 724, 760, 761]
# Vertex 133:
# Faces: [180, 369, 490, 1796, 1940, 2359, 5760]
# Vertex 134:
# Faces: [248, 1029, 2572, 2633, 2728, 2857, 2905]
# Vertex 135:
# Faces: [608, 3225, 3352, 3418]
# Vertex 136:
# Faces: [658, 659, 674, 683, 717, 730, 731]
# Vertex 137:
# Faces: [1142, 1157, 1170, 3197, 3216]
# Vertex 138:
# Faces: [1141, 1142, 1170, 1195, 1206]
# Vertex 139:
# Faces: [254, 354, 404, 442, 726]
# Vertex 140:
# Faces: [786, 1006, 1742, 2517, 2819]
# Vertex 141:
# Faces: [385, 975, 1124, 2860, 3040, 3062]
# Vertex 142:
# Faces: [491, 1209, 1766, 1805, 1904, 1905]
# Vertex 143:
# Faces: [608, 624, 641, 658, 659, 3418]
# Vertex 144:
# Faces: [717, 731, 754, 794, 795]
# Vertex 145:
# Faces: [794, 795, 824, 825, 862, 863, 3104, 3146, 3584]
# Vertex 146:
# Faces: [3104, 3134, 3152, 3261, 3584]
# Vertex 147:
# Faces: [486, 855, 1138, 1195, 1206]
# Vertex 148:
# Faces: [254, 257, 272, 354, 585]
# Vertex 149:
# Faces: [254, 255, 272, 442, 582, 784]
# Vertex 150:
# Faces: [214, 240, 241, 255, 582]
# Vertex 151:
# Faces: [180, 369, 408, 412, 1059, 1077]
# Vertex 152:
# Faces: [408, 412, 491, 978, 1905]
# Vertex 153:
# Faces: [42, 196, 317, 843, 880]
# Vertex 154:
# Faces: [213, 238, 240, 456, 582, 647, 784]
# Vertex 155:
# Faces: [30, 84, 514, 2084, 2226, 4111]
# Vertex 156:
# Faces: [91, 107, 124, 139, 150, 167, 168, 3493]
# Vertex 157:
# Faces: [369, 1045, 1059, 1484, 1799, 5760]
# Vertex 158:
# Faces: [978, 979, 1319, 1730, 1746, 1805, 1905]
# Vertex 159:
# Faces: [300, 314, 420, 545, 547, 607, 948, 1007]
# Vertex 160:
# Faces: [2664, 2717, 4592, 4608, 4619, 5314]
# Vertex 161:
# Faces: [754, 755, 756, 768, 795, 806, 825]
# Vertex 162:
# Faces: [806, 825, 826, 863, 864]
# Vertex 163:
# Faces: [1065, 2612, 3249, 3315, 5275, 5574]
# Vertex 164:
# Faces: [368, 803, 855, 1141, 1143, 1195, 1196]
# Vertex 165:
# Faces: [257, 368, 486, 585, 855]
# Vertex 166:
# Faces: [4327, 4328, 4626, 5026, 5511]
# Vertex 167:
# Faces: [711, 1135, 1136, 1188, 1189, 6340]
# Vertex 168:
# Faces: [201, 256, 337, 383, 526, 976, 2753, 2964]
# Vertex 169:
# Faces: [412, 507, 800, 978, 979, 1045, 1059]
# Vertex 170:
# Faces: [28, 982, 2663, 2783, 2888]
# Vertex 171:
# Faces: [52, 449, 3210, 3217, 3233, 6091]
# Vertex 172:
# Faces: [624, 625, 626, 659, 660, 674, 675]
# Vertex 173:
# Faces: [674, 675, 697, 717, 754, 755]
# Vertex 174:
# Faces: [863, 864, 865, 883, 3104, 3134, 3189]
# Vertex 175:
# Faces: [1100, 3539, 4770, 5275, 5574]
# Vertex 176:
# Faces: [1141, 1142, 1143, 3197, 3315, 3539, 5574]
# Vertex 177:
# Faces: [272, 368, 439, 443, 456, 585, 784, 803]
# Vertex 178:
# Faces: [213, 238, 401, 765, 1269, 1479, 1655, 1768, 1876]
# Vertex 179:
# Faces: [117, 302, 446, 2196, 2678]
# Vertex 180:
# Faces: [81, 556, 3111, 3246, 3305, 3373]
# Vertex 181:
# Faces: [1114, 3374, 3559, 3830, 5301]
# Vertex 182:
# Faces: [2912, 2920, 2924, 2959, 2982, 2999, 3000, 3011]
# Vertex 183:
# Faces: [232, 443, 456, 470, 472, 647, 946]
# Vertex 184:
# Faces: [238, 470, 647, 765]
# Vertex 185:
# Faces: [3895, 3914, 3928, 3977, 3978, 4474, 5226]
# Vertex 186:
# Faces: [6521, 6534, 6535, 6583, 6584, 6585]
# Vertex 187:
# Faces: [224, 318, 982, 2652, 2865, 2888, 2931, 3002]
# Vertex 188:
# Faces: [33, 2569, 2757, 2774, 2921, 2926]
# Vertex 189:
# Faces: [660, 661, 675, 697]
# Vertex 190:
# Faces: [661, 662, 684, 697, 732, 755, 756]
# Vertex 191:
# Faces: [1066, 1099, 1100, 3249, 3273, 3347, 5275]
# Vertex 192:
# Faces: [1127, 1143, 1171, 1179, 1196, 3539, 4770]
# Vertex 193:
# Faces: [236, 439, 803, 896, 1179, 1196]
# Vertex 194:
# Faces: [76, 507, 617, 800, 1178, 2610]
# Vertex 195:
# Faces: [800, 979, 1178, 1746]
# Vertex 196:
# Faces: [1099, 1100, 1101, 1115, 1127, 4770]
# Vertex 197:
# Faces: [232, 236, 364, 439, 443]
# Vertex 198:
# Faces: [399, 1797, 4497, 4532, 4753]
# Vertex 199:
# Faces: [385, 962, 1124, 1125, 1523, 1973]
# Vertex 200:
# Faces: [421, 507, 617, 1045, 1279, 1484]
# Vertex 201:
# Faces: [3672, 3674, 3682, 3683, 3684, 4381]
# Vertex 202:
# Faces: [2659, 2707, 2765, 2824, 2908, 3008]
# Vertex 203:
# Faces: [590, 609, 626, 660, 661, 662, 663]
# Vertex 204:
# Faces: [732, 756, 768, 769, 770]
# Vertex 205:
# Faces: [826, 827, 864, 865, 867]
# Vertex 206:
# Faces: [865, 866, 867, 883, 3188, 3271, 3274]
# Vertex 207:
# Faces: [1048, 1066, 1067, 3347, 5163]
# Vertex 208:
# Faces: [1066, 1067, 1099, 1101, 1102]
# Vertex 209:
# Faces: [232, 364, 382, 839, 946]
# Vertex 210:
# Faces: [267, 707, 725, 2809, 2898]
# Vertex 211:
# Faces: [1463, 1748, 4058, 5794, 5831]
# Vertex 212:
# Faces: [3069, 3109, 3227, 3468, 3627, 5186]
# Vertex 213:
# Faces: [4451, 4622, 4748, 5619, 5633, 6614]
# Vertex 214:
# Faces: [575, 590, 591, 609, 6790]
# Vertex 215:
# Faces: [768, 769, 806, 807, 826, 827]
# Vertex 216:
# Faces: [828, 866, 1008, 2952, 3188, 3351]
# Vertex 217:
# Faces: [2616, 2620, 2621, 2627, 2629, 2836]
# Vertex 218:
# Faces: [1048, 1049, 1067, 1068, 1102, 1103, 1104]
# Vertex 219:
# Faces: [1101, 1102, 1103, 1115]
# Vertex 220:
# Faces: [1103, 1104, 1115, 1127, 1144, 1171, 1172]
# Vertex 221:
# Faces: [236, 364, 727, 839, 896, 1207]
# Vertex 222:
# Faces: [260, 401, 1262, 1479, 1574]
# Vertex 223:
# Faces: [531, 845, 2148, 2149, 2370]
# Vertex 224:
# Faces: [256, 311, 337, 711, 878, 1187, 1188]
# Vertex 225:
# Faces: [1, 11, 2266, 2411, 4419, 4420]
# Vertex 226:
# Faces: [2163, 2354, 2355, 2664, 2790, 5169, 5314]
# Vertex 227:
# Faces: [769, 770, 771, 807, 808]
# Vertex 228:
# Faces: [3756, 3801, 3803, 3812, 3913, 4625, 4636]
# Vertex 229:
# Faces: [2077, 3916, 4064, 4101, 4158]
# Vertex 230:
# Faces: [4481, 4490, 4713, 5494, 5499]
# Vertex 231:
# Faces: [451, 481, 517, 518, 6704, 6723]
# Vertex 232:
# Faces: [517, 575, 6723, 6751, 6777, 6790]
# Vertex 233:
# Faces: [591, 592, 609, 610, 663, 664]
# Vertex 234:
# Faces: [215, 655, 870, 905, 975, 3062]
# Vertex 235:
# Faces: [1068, 1084, 1104, 1116, 1144, 1145]
# Vertex 236:
# Faces: [896, 1171, 1172, 1179, 1197, 1207]
# Vertex 237:
# Faces: [230, 233, 253, 382, 472, 946]
# Vertex 238:
# Faces: [1018, 1054, 1075, 1087]
# Vertex 239:
# Faces: [1765, 2285, 2286, 2323, 2406, 2688]
# Vertex 240:
# Faces: [993, 2139, 3790, 5065, 5077, 6183]
# Vertex 241:
# Faces: [328, 376, 389, 414, 6092, 6104]
# Vertex 242:
# Faces: [517, 518, 557, 575, 591, 592]
# Vertex 243:
# Faces: [662, 663, 664, 676, 684, 698, 718]
# Vertex 244:
# Faces: [233, 382, 727, 839, 898, 949]
# Vertex 245:
# Faces: [256, 311, 976, 1056]
# Vertex 246:
# Faces: [974, 991, 1004, 1018, 1037, 1054]
# Vertex 247:
# Faces: [2901, 2902, 2920, 2925, 2959, 2960]
# Vertex 248:
# Faces: [18, 372, 2556, 2788, 2943, 3041]
# Vertex 249:
# Faces: [376, 388, 414, 429, 451, 6688, 6704]
# Vertex 250:
# Faces: [684, 718, 732, 770, 771, 772]
# Vertex 251:
# Faces: [771, 772, 796, 808, 828, 838, 1008]
# Vertex 252:
# Faces: [807, 808, 827, 828, 866, 867]
# Vertex 253:
# Faces: [1011, 1031, 1049, 1050, 1068, 1084]
# Vertex 254:
# Faces: [1144, 1145, 1172, 1173, 1180, 1197, 1198]
# Vertex 255:
# Faces: [212, 1180, 1198, 1199, 1208]
# Vertex 256:
# Faces: [212, 727, 949, 1197, 1198, 1207]
# Vertex 257:
# Faces: [230, 260, 401, 470, 472, 765, 1024]
# Vertex 258:
# Faces: [150, 167, 1251, 1258, 1277, 1284]
# Vertex 259:
# Faces: [372, 2735, 2943, 3136, 3616]
# Vertex 260:
# Faces: [289, 306, 328, 329, 6104, 6838]
# Vertex 261:
# Faces: [610, 611, 642, 664, 676, 677]
# Vertex 262:
# Faces: [27, 1011, 1012, 1031, 3228, 3284, 3381]
# Vertex 263:
# Faces: [233, 239, 253, 654, 895, 898]
# Vertex 264:
# Faces: [724, 725, 761, 2809, 3102, 3364]
# Vertex 265:
# Faces: [305, 913, 914, 931, 961, 1231]
# Vertex 266:
# Faces: [1075, 1087, 1088, 1134, 1135, 1136, 1137]
# Vertex 267:
# Faces: [100, 573, 884, 925, 927]
# Vertex 268:
# Faces: [87, 131, 529, 530, 1773, 1834]
# Vertex 269:
# Faces: [858, 1538, 1570, 2778, 3003]
# Vertex 270:
# Faces: [926, 1009, 1029, 2662, 2905]
# Vertex 271:
# Faces: [328, 329, 330, 377, 389, 390]
# Vertex 272:
# Faces: [481, 498, 518, 535, 557, 558]
# Vertex 273:
# Faces: [557, 558, 592, 593, 610, 611]
# Vertex 274:
# Faces: [676, 677, 698, 699, 719]
# Vertex 275:
# Faces: [698, 718, 719, 740, 757, 772, 796]
# Vertex 276:
# Faces: [1012, 1031, 1032, 1050, 1069]
# Vertex 277:
# Faces: [820, 878, 1187, 1203]
# Vertex 278:
# Faces: [201, 383, 1125, 1695, 1973]
# Vertex 279:
# Faces: [93, 2673, 3293, 3574, 3612, 6079]
# Vertex 280:
# Faces: [2598, 2599, 2724, 2805, 2891, 2915, 2980]
# Vertex 281:
# Faces: [306, 307, 329, 330]
# Vertex 282:
# Faces: [377, 378, 390, 392, 415]
# Vertex 283:
# Faces: [429, 451, 452, 481, 498, 499]
# Vertex 284:
# Faces: [498, 499, 500, 519, 535, 559]
# Vertex 285:
# Faces: [642, 643, 665, 677, 699, 700]
# Vertex 286:
# Faces: [757, 796, 797, 809, 829, 838]
# Vertex 287:
# Faces: [248, 2572, 2723, 3213, 3408, 4121]
# Vertex 288:
# Faces: [1116, 1117, 1145, 1146, 1173]
# Vertex 289:
# Faces: [1146, 1147, 1173, 1180, 1199, 1200]
# Vertex 290:
# Faces: [230, 253, 654, 1023, 1024]
# Vertex 291:
# Faces: [14, 851, 913, 914]
# Vertex 292:
# Faces: [1133, 1134, 1135, 1186, 1187, 1188, 1203]
# Vertex 293:
# Faces: [81, 82, 106, 134, 135, 3111]
# Vertex 294:
# Faces: [694, 712, 1628, 2014, 2034]
# Vertex 295:
# Faces: [33, 2657, 2659, 2768, 2921, 3008, 3021]
# Vertex 296:
# Faces: [114, 246, 265, 2879, 2990]
# Vertex 297:
# Faces: [389, 390, 414, 415, 429, 430, 452]
# Vertex 298:
# Faces: [430, 452, 482, 499, 500]
# Vertex 299:
# Faces: [535, 558, 559, 593, 594, 595]
# Vertex 300:
# Faces: [593, 595, 611, 627, 642, 643]
# Vertex 301:
# Faces: [665, 666, 667, 700, 701]
# Vertex 302:
# Faces: [699, 700, 701, 719, 733, 740, 741]
# Vertex 303:
# Faces: [740, 741, 757, 773, 797]
# Vertex 304:
# Faces: [809, 810, 829, 830, 832, 3161]
# Vertex 305:
# Faces: [1050, 1069, 1070, 1084, 1105, 1116, 1117]
# Vertex 306:
# Faces: [283, 1043, 1199, 1200, 1208]
# Vertex 307:
# Faces: [212, 239, 283, 384, 898, 949, 1208]
# Vertex 308:
# Faces: [931, 944, 945, 961, 974, 992, 1004]
# Vertex 309:
# Faces: [12, 550, 605, 619, 2722]
# Vertex 310:
# Faces: [494, 602, 1637, 1669, 2021, 3050]
# Vertex 311:
# Faces: [2438, 2454, 2482, 2497, 2527, 2529]
# Vertex 312:
# Faces: [160, 1607, 2527, 2528, 2529, 2543, 2810]
# Vertex 313:
# Faces: [170, 341, 366, 636, 1055, 2025]
# Vertex 314:
# Faces: [2679, 2705, 2781, 2791, 2792]
# Vertex 315:
# Faces: [1778, 1917, 3015, 3019, 3429]
# Vertex 316:
# Faces: [519, 536, 559, 594, 596]
# Vertex 317:
# Faces: [1002, 1032, 1033, 1069, 1070, 3116]
# Vertex 318:
# Faces: [1033, 1051, 1070, 1071, 1105, 1106]
# Vertex 319:
# Faces: [821, 1043, 1147, 1148, 1159, 1200]
# Vertex 320:
# Faces: [234, 283, 334, 384, 821, 879, 1043]
# Vertex 321:
# Faces: [234, 239, 384, 488, 895, 1166]
# Vertex 322:
# Faces: [19, 247, 478, 479, 2622]
# Vertex 323:
# Faces: [337, 711, 766, 2753, 6340]
# Vertex 324:
# Faces: [638, 653, 694, 712, 713, 3078]
# Vertex 325:
# Faces: [33, 316, 2707, 2926, 2995, 3008]
# Vertex 326:
# Faces: [316, 343, 2603, 2752, 2994, 2995]
# Vertex 327:
# Faces: [904, 985, 2824, 2900, 2908, 3054]
# Vertex 328:
# Faces: [269, 280, 306, 307, 308, 6054, 6838]
# Vertex 329:
# Faces: [307, 308, 330, 344, 377, 378]
# Vertex 330:
# Faces: [482, 483, 500, 519, 520, 536]
# Vertex 331:
# Faces: [627, 628, 643, 644, 665, 666]
# Vertex 332:
# Faces: [720, 721, 733, 734, 741, 773, 774]
# Vertex 333:
# Faces: [1105, 1106, 1117, 1128, 1146, 1147, 1148]
# Vertex 334:
# Faces: [488, 583, 709, 1078, 1166]
# Vertex 335:
# Faces: [2842, 2843, 2861, 2887, 2901, 2912, 2920]
# Vertex 336:
# Faces: [580, 600, 602, 614, 634, 3050]
# Vertex 337:
# Faces: [915, 1538, 1570, 1640, 2740, 2866]
# Vertex 338:
# Faces: [249, 269, 3141, 3172, 3173, 6054]
# Vertex 339:
# Faces: [391, 392, 415, 430, 431, 462, 482, 483]
# Vertex 340:
# Faces: [734, 758, 774, 775, 776]
# Vertex 341:
# Faces: [773, 774, 775, 797, 809, 810]
# Vertex 342:
# Faces: [37, 181, 2630, 4476, 4694, 4825, 4871]
# Vertex 343:
# Faces: [99, 132, 143, 162, 164, 516]
# Vertex 344:
# Faces: [193, 583, 1078, 1217, 1657, 1776]
# Vertex 345:
# Faces: [637, 1462, 1521, 1593, 1597, 1651, 2437]
# Vertex 346:
# Faces: [955, 1114, 3803, 3812, 5301]
# Vertex 347:
# Faces: [3801, 3802, 3812, 3830, 5301]
# Vertex 348:
# Faces: [2481, 2482, 2519, 2527, 2528, 2539]
# Vertex 349:
# Faces: [13, 32, 70, 96, 941, 985, 3054]
# Vertex 350:
# Faces: [789, 836, 2556, 2788, 3046, 6199]
# Vertex 351:
# Faces: [249, 269, 270, 280, 290]
# Vertex 352:
# Faces: [280, 290, 308, 319, 344, 345]
# Vertex 353:
# Faces: [344, 345, 378, 379, 391, 392]
# Vertex 354:
# Faces: [644, 666, 667, 668, 685, 686]
# Vertex 355:
# Faces: [667, 685, 701, 721, 733]
# Vertex 356:
# Faces: [234, 334, 473, 488, 546, 709]
# Vertex 357:
# Faces: [605, 619, 652, 1991]
# Vertex 358:
# Faces: [425, 549, 637, 1558, 1693, 2437]
# Vertex 359:
# Faces: [170, 245, 636, 1797, 4497]
# Vertex 360:
# Faces: [992, 1004, 1018, 1075, 1088, 2047, 2738]
# Vertex 361:
# Faces: [2187, 2387, 4368, 4369, 4370, 4393, 4396]
# Vertex 362:
# Faces: [62, 63, 588, 1505, 1506, 1531, 2648, 4635]
# Vertex 363:
# Faces: [319, 345, 346, 360, 379]
# Vertex 364:
# Faces: [520, 536, 537, 576, 596, 597]
# Vertex 365:
# Faces: [594, 595, 596, 597, 627, 628, 629]
# Vertex 366:
# Faces: [560, 576, 597, 629, 631]
# Vertex 367:
# Faces: [628, 629, 630, 631, 644, 668]
# Vertex 368:
# Faces: [685, 686, 687, 720, 721, 722, 735]
# Vertex 369:
# Faces: [775, 776, 810, 811, 833, 3161]
# Vertex 370:
# Faces: [1071, 1106, 1107, 1128, 1129]
# Vertex 371:
# Faces: [1128, 1129, 1148, 1159, 1160]
# Vertex 372:
# Faces: [821, 879, 1159, 1160, 1201]
# Vertex 373:
# Faces: [294, 2528, 2539, 2540, 2543]
# Vertex 374:
# Faces: [360, 379, 391, 431, 432]
# Vertex 375:
# Faces: [462, 483, 484, 501, 520, 537]
# Vertex 376:
# Faces: [720, 734, 735, 758]
# Vertex 377:
# Faces: [1107, 1118, 1129, 1160, 1174, 1181, 1201]
# Vertex 378:
# Faces: [57, 92, 99, 100, 143, 207, 573]
# Vertex 379:
# Faces: [600, 601, 634, 678, 704, 705, 706]
# Vertex 380:
# Faces: [1377, 1389, 1554, 1727, 2235, 3852]
# Vertex 381:
# Faces: [2, 152, 196, 317, 496, 555, 715]
# Vertex 382:
# Faces: [346, 360, 361, 416, 432, 433]
# Vertex 383:
# Faces: [431, 432, 433, 453, 462, 484]
# Vertex 384:
# Faces: [453, 463, 484, 501, 502]
# Vertex 385:
# Faces: [501, 502, 537, 538, 560, 576]
# Vertex 386:
# Faces: [722, 735, 742, 758, 776, 777, 798, 811]
# Vertex 387:
# Faces: [798, 811, 812, 833, 3171, 3232, 3252, 3399]
# Vertex 388:
# Faces: [1052, 2934, 3086, 3239, 3499]
# Vertex 389:
# Faces: [301, 334, 473, 856, 879, 1181, 1201]
# Vertex 390:
# Faces: [83, 90, 107, 3359, 3493]
# Vertex 391:
# Faces: [2959, 2960, 2983, 2989, 3000, 3001]
# Vertex 392:
# Faces: [65, 208, 2565, 2611, 5248]
# Vertex 393:
# Faces: [200, 210, 3091, 3240, 3412]
# Vertex 394:
# Faces: [200, 210, 227, 250, 271]
# Vertex 395:
# Faces: [210, 249, 250, 270, 3141, 3240]
# Vertex 396:
# Faces: [250, 270, 271, 281, 290, 319, 320, 346, 361]
# Vertex 397:
# Faces: [630, 632, 668, 669, 686, 687, 688]
# Vertex 398:
# Faces: [812, 847, 871, 3232]
# Vertex 399:
# Faces: [847, 848, 871, 889, 929]
# Vertex 400:
# Faces: [1051, 1052, 1071, 1107, 1118, 1130, 3239]
# Vertex 401:
# Faces: [193, 352, 546, 709, 1078, 1111]
# Vertex 402:
# Faces: [277, 278, 352, 541, 569, 1091, 1111]
# Vertex 403:
# Faces: [148, 155, 187, 1510, 1550, 2039, 2953]
# Vertex 404:
# Faces: [1446, 1447, 1448, 1449, 1474, 1504, 1505, 1506]
# Vertex 405:
# Faces: [160, 2670, 2787, 2810, 2811, 2837, 2838]
# Vertex 406:
# Faces: [971, 2324, 2860, 3013, 3040]
# Vertex 407:
# Faces: [380, 381, 416, 433, 434, 453, 463, 464, 465]
# Vertex 408:
# Faces: [687, 688, 702, 722, 742, 743, 744]
# Vertex 409:
# Faces: [777, 798, 812, 813, 847, 848]
# Vertex 410:
# Faces: [19, 42, 804, 805, 843, 2622]
# Vertex 411:
# Faces: [1118, 1130, 1174, 1175, 3029]
# Vertex 412:
# Faces: [301, 1174, 1175, 1181, 2637, 2986]
# Vertex 413:
# Faces: [350, 473, 546, 856, 1091, 1111]
# Vertex 414:
# Faces: [278, 398, 569, 1525, 1764]
# Vertex 415:
# Faces: [788, 789, 836, 1833, 2043, 3009]
# Vertex 416:
# Faces: [281, 309, 320, 321, 331]
# Vertex 417:
# Faces: [320, 331, 361, 380, 416]
# Vertex 418:
# Faces: [889, 890, 909, 929, 3423]
# Vertex 419:
# Faces: [1175, 1204, 2637, 3029, 3045]
# Vertex 420:
# Faces: [298, 350, 400, 541, 1091, 2741]
# Vertex 421:
# Faces: [285, 403, 425, 1218, 1558]
# Vertex 422:
# Faces: [403, 425, 549, 1617, 1873, 2321]
# Vertex 423:
# Faces: [399, 2549, 2893, 4442, 4753]
# Vertex 424:
# Faces: [2695, 2696, 2756, 2776, 2896]
# Vertex 425:
# Faces: [2, 3, 37, 152, 181, 182]
# Vertex 426:
# Faces: [321, 331, 347, 380, 381]
# Vertex 427:
# Faces: [463, 464, 502, 538, 539, 561]
# Vertex 428:
# Faces: [538, 560, 561, 598, 612, 630, 631, 632]
# Vertex 429:
# Faces: [669, 688, 689, 702, 703]
# Vertex 430:
# Faces: [742, 744, 777, 813, 814]
# Vertex 431:
# Faces: [813, 814, 834, 848, 889, 890]
# Vertex 432:
# Faces: [243, 422, 1750, 1774, 1801, 1984, 2484]
# Vertex 433:
# Faces: [1204, 2637, 2978, 2986, 3004, 3819]
# Vertex 434:
# Faces: [301, 350, 856, 2741, 2986, 3819]
# Vertex 435:
# Faces: [276, 298, 398, 541, 569, 749, 840, 841]
# Vertex 436:
# Faces: [285, 398, 749, 963, 1218, 1525]
# Vertex 437:
# Faces: [134, 148, 149, 155, 556, 2979, 3111]
# Vertex 438:
# Faces: [6, 8, 50, 266, 267, 2809, 3102]
# Vertex 439:
# Faces: [93, 2673, 2724, 2891, 2937]
# Vertex 440:
# Faces: [83, 90, 106, 123, 135, 136, 137, 3245]
# Vertex 441:
# Faces: [183, 211, 228, 229, 251]
# Vertex 442:
# Faces: [434, 435, 455, 465, 466]
# Vertex 443:
# Faces: [539, 540, 561, 562, 598, 599]
# Vertex 444:
# Faces: [689, 690, 691, 703, 723, 736]
# Vertex 445:
# Faces: [702, 703, 736, 743, 759]
# Vertex 446:
# Faces: [943, 972, 3105, 3505, 3550]
# Vertex 447:
# Faces: [1526, 1727, 2495, 3852, 3940, 3975, 5435]
# Vertex 448:
# Faces: [276, 298, 400, 487, 763]
# Vertex 449:
# Faces: [335, 749, 840, 963]
# Vertex 450:
# Faces: [2, 3, 224, 318, 715, 4564]
# Vertex 451:
# Faces: [941, 2765, 2803, 2908, 3054]
# Vertex 452:
# Faces: [6612, 6613, 6638, 6649, 6671]
# Vertex 453:
# Faces: [53, 1120, 3038, 3039, 3059]
# Vertex 454:
# Faces: [227, 228, 251, 271, 281, 291, 309]
# Vertex 455:
# Faces: [612, 632, 645, 669, 689, 690]
# Vertex 456:
# Faces: [723, 736, 759, 778, 779]
# Vertex 457:
# Faces: [834, 835, 872, 890, 909, 910]
# Vertex 458:
# Faces: [872, 891, 910, 930, 943, 3550]
# Vertex 459:
# Faces: [1149, 1162, 3250, 3400]
# Vertex 460:
# Faces: [2131, 2387, 2981, 4395, 4396]
# Vertex 461:
# Faces: [177, 186, 276, 351, 763, 841]
# Vertex 462:
# Faces: [186, 335, 397, 822, 840, 841]
# Vertex 463:
# Faces: [285, 335, 397, 403, 418, 963, 1528, 2321]
# Vertex 464:
# Faces: [12, 568, 605, 1888, 1951, 1991]
# Vertex 465:
# Faces: [2598, 2599, 2728, 2857, 2945, 2972]
# Vertex 466:
# Faces: [464, 465, 466, 503, 539, 540]
# Vertex 467:
# Faces: [503, 504, 521, 540, 562, 563]
# Vertex 468:
# Faces: [1149, 1150, 1162, 1778, 2007, 3429]
# Vertex 469:
# Faces: [4, 35, 224, 496, 715, 3002]
# Vertex 470:
# Faces: [310, 333, 618, 1165, 2970]
# Vertex 471:
# Faces: [177, 186, 340, 787, 822]
# Vertex 472:
# Faces: [614, 634, 706, 707, 724, 725, 2162]
# Vertex 473:
# Faces: [57, 132, 143, 152, 182, 555]
# Vertex 474:
# Faces: [175, 176, 3322, 3350, 3370, 3481, 6441]
# Vertex 475:
# Faces: [229, 251, 252, 291, 292]
# Vertex 476:
# Faces: [291, 292, 293, 309, 321, 322, 347, 348, 362, 363]
# Vertex 477:
# Faces: [598, 599, 612, 613, 633, 645]
# Vertex 478:
# Faces: [815, 816, 835, 872, 891, 892]
# Vertex 479:
# Faces: [988, 989, 1015, 1016, 3415]
# Vertex 480:
# Faces: [1035, 1036, 1074, 1086, 3095]
# Vertex 481:
# Faces: [177, 310, 333, 340, 351, 1167]
# Vertex 482:
# Faces: [231, 418, 419, 581, 1388, 1528]
# Vertex 483:
# Faces: [201, 215, 975, 1124, 1125, 2964]
# Vertex 484:
# Faces: [1295, 1571, 2469, 2481, 2506, 2519, 2526, 2538]
# Vertex 485:
# Faces: [124, 168, 906, 2666, 2716, 4036, 6226]
# Vertex 486:
# Faces: [347, 362, 381, 393, 434, 435]
# Vertex 487:
# Faces: [454, 455, 466, 485, 503, 504]
# Vertex 488:
# Faces: [467, 485, 504, 521, 522]
# Vertex 489:
# Faces: [562, 563, 577, 599, 613]
# Vertex 490:
# Faces: [691, 692, 723, 745, 778]
# Vertex 491:
# Faces: [743, 744, 759, 779, 814, 815, 834, 835]
# Vertex 492:
# Faces: [1015, 1016, 1035, 1085, 1086, 3835]
# Vertex 493:
# Faces: [286, 296, 570, 618, 1165, 1786]
# Vertex 494:
# Faces: [707, 2162, 2782, 2820, 2898]
# Vertex 495:
# Faces: [2811, 2838, 2842, 2877, 2887]
# Vertex 496:
# Faces: [1974, 2355, 2569, 2639, 2664, 2717, 2757]
# Vertex 497:
# Faces: [2598, 2673, 2724, 2795, 2972, 6079]
# Vertex 498:
# Faces: [279, 2735, 2813, 3195, 3502, 3616]
# Vertex 499:
# Faces: [3322, 3519, 6304, 6321, 6441]
# Vertex 500:
# Faces: [362, 363, 393]
# Vertex 501:
# Faces: [633, 645, 670, 690, 691, 692]
# Vertex 502:
# Faces: [930, 943, 972, 973, 988, 989, 990]
# Vertex 503:
# Faces: [1074, 1121, 1151, 3095, 5165]
# Vertex 504:
# Faces: [1150, 1151, 1163, 1184, 2007, 5165]
# Vertex 505:
# Faces: [286, 332, 897, 1168, 1183, 1786]
# Vertex 506:
# Faces: [53, 884, 927, 984, 1120, 1549]
# Vertex 507:
# Faces: [2086, 3150, 4178, 4196, 4769]
# Vertex 508:
# Faces: [577, 578, 613, 633, 646, 670]
# Vertex 509:
# Faces: [745, 746, 778, 779, 780, 815, 816]
# Vertex 510:
# Faces: [891, 892, 911, 930, 960, 973]
# Vertex 511:
# Faces: [989, 990, 1016, 1017, 1035, 1036]
# Vertex 512:
# Faces: [332, 440, 897, 1163, 1184, 1185]
# Vertex 513:
# Faces: [340, 679, 764, 787, 917, 1167]
# Vertex 514:
# Faces: [397, 418, 419, 457, 764, 787, 822]
# Vertex 515:
# Faces: [231, 581, 584, 607, 1007, 1039]
# Vertex 516:
# Faces: [1109, 1291, 1561, 1767, 1825, 1913, 2057]
# Vertex 517:
# Faces: [134, 135, 136, 149, 156, 157]
# Vertex 518:
# Faces: [349, 396, 1486, 3132]
# Vertex 519:
# Faces: [3000, 3001, 3011, 3026, 3038, 3039]
# Vertex 520:
# Faces: [2989, 3001, 3017, 3026]
# Vertex 521:
# Faces: [185, 2660, 3821, 6381, 6412]
# Vertex 522:
# Faces: [293, 322, 323, 1378, 1832, 2005]
# Vertex 523:
# Faces: [436, 454, 467, 485]
# Vertex 524:
# Faces: [646, 670, 678, 692, 704, 745, 746]
# Vertex 525:
# Faces: [780, 816, 817, 849, 892, 911, 912]
# Vertex 526:
# Faces: [1121, 1122, 1133, 1151, 1163, 1185, 1186]
# Vertex 527:
# Faces: [310, 570, 917, 950, 1165, 1167, 1644]
# Vertex 528:
# Faces: [474, 679, 710, 917, 1644, 1931]
# Vertex 529:
# Faces: [457, 650, 679, 710, 764]
# Vertex 530:
# Faces: [489, 584, 1039, 1109, 1110, 1291]
# Vertex 531:
# Faces: [395, 396, 437, 468, 505, 1486]
# Vertex 532:
# Faces: [175, 176, 185, 211, 229, 252, 1271, 2660]
# Vertex 533:
# Faces: [348, 363, 393, 394, 435, 436, 454, 455]
# Vertex 534:
# Faces: [394, 395, 436, 467, 468, 522, 523]
# Vertex 535:
# Faces: [521, 522, 523, 563, 577, 578, 579]
# Vertex 536:
# Faces: [578, 579, 601, 646, 678]
# Vertex 537:
# Faces: [286, 295, 570, 950, 1057, 1168]
# Vertex 538:
# Faces: [300, 420, 474, 492, 650, 710]
# Vertex 539:
# Faces: [489, 547, 584, 1007]
# Vertex 540:
# Faces: [468, 505, 523, 524, 579, 580, 600, 601]
# Vertex 541:
# Faces: [4327, 4369, 4370, 5125, 5501, 5511]
# Vertex 542:
# Faces: [14, 760, 761, 817, 849, 850, 851, 3364]
# Vertex 543:
# Faces: [960, 973, 990, 991, 1017, 1037, 1053]
# Vertex 544:
# Faces: [311, 820, 878, 1056, 1057, 1168, 1183]
# Vertex 545:
# Faces: [961, 964, 992, 1022, 1231, 2738]
# Vertex 546:
# Faces: [300, 419, 457, 581, 607, 650]
# Vertex 547:
# Faces: [3910, 3946, 3947, 3999, 4000, 4031]
# Vertex 548:
# Faces: [341, 366, 933, 1164, 2329, 2498, 2507, 4719, 4980]
# Vertex 549:
# Faces: [737, 750, 788, 836, 1278, 6199]
# Vertex 550:
# Faces: [2226, 2698, 3878, 4111, 6055, 6068, 6818]
# Vertex 551:
# Faces: [738, 750, 1278, 1970, 2046]
# Vertex 552:
# Faces: [323, 349, 525, 1390, 1832, 3132]
# Vertex 553:
# Faces: [322, 323, 348, 349, 394, 395, 396]
# Vertex 554:
# Faces: [704, 705, 746, 760, 780, 817]
# Vertex 555:
# Faces: [3263, 5161, 5187, 5470, 5472, 5868]
# Vertex 556:
# Faces: [5586, 5608, 5635, 5636, 5927]
# Vertex 557:
# Faces: [1943, 2861, 2874, 2901, 2902]
# Vertex 558:
# Faces: [2652, 2677, 2685, 2759, 2760, 2783, 2888]
# Vertex 559:
# Faces: [1758, 3285, 6015, 6308, 6724]
# Vertex 560:
# Faces: [1326, 1520, 1650, 1924, 2435, 2511]
# Vertex 561:
# Faces: [1395, 1409, 1422, 1423, 2584]
# Vertex 562:
# Faces: [1476, 1516, 3310, 3463, 6139, 6249, 6817]
# Vertex 563:
# Faces: [1954, 1971, 2018, 2019, 6066]
# Vertex 564:
# Faces: [1412, 1650, 1883, 2435, 4824, 4833, 6259]
# Vertex 565:
# Faces: [78, 739, 970, 983, 2244, 2251]
# Vertex 566:
# Faces: [1268, 1410, 1433, 1476, 1509, 6249]
# Vertex 567:
# Faces: [1625, 1763, 3244, 3431, 3433]
# Vertex 568:
# Faces: [1090, 1542, 1758, 2018, 2019, 2068, 3285]
# Vertex 569:
# Faces: [1040, 1210, 1412, 1635, 1643, 1676, 1828, 1883]
# Vertex 570:
# Faces: [1295, 1851, 1996, 2454, 2481, 2482]
# Vertex 571:
# Faces: [409, 410, 1410, 1432, 1433, 3421]
# Vertex 572:
# Faces: [1476, 1509, 1516, 1533, 3224]
# Vertex 573:
# Faces: [1232, 1533, 3121, 3139, 3167, 3224, 3247]
# Vertex 574:
# Faces: [1431, 1656, 1763, 1835, 1847, 2941, 3433, 6762]
# Vertex 575:
# Faces: [1431, 1626, 1847, 1903]
# Vertex 576:
# Faces: [235, 1169, 1191, 1542, 1626, 1903, 1954, 2019]
# Vertex 577:
# Faces: [1497, 1499, 1635, 1676]
# Vertex 578:
# Faces: [1499, 1520, 1539, 1650, 1676, 1883]
# Vertex 579:
# Faces: [1363, 1520, 1539, 1598, 1619, 1924, 1957]
# Vertex 580:
# Faces: [3590, 4988, 5149, 5177, 5325]
# Vertex 581:
# Faces: [553, 554, 571, 622, 1268, 1509, 1533, 3139]
# Vertex 582:
# Faces: [61, 294, 799, 1055, 1108, 2025, 2532, 2540]
# Vertex 583:
# Faces: [263, 1439, 1522, 1529, 1559, 1755, 2059]
# Vertex 584:
# Faces: [1547, 1553, 1584, 1707, 1777, 1837, 1893]
# Vertex 585:
# Faces: [1210, 1223, 1675, 1793, 1828]
# Vertex 586:
# Faces: [1210, 1469, 1497, 1635, 1675, 2023]
# Vertex 587:
# Faces: [1259, 1598, 1619, 1867, 1994, 2029, 2233]
# Vertex 588:
# Faces: [1780, 1792, 1823, 1994, 2029]
# Vertex 589:
# Faces: [1240, 1780, 1792, 1866, 3564, 6427]
# Vertex 590:
# Faces: [3620, 4092, 5035, 5053, 5099, 5101, 5829]
# Vertex 591:
# Faces: [5149, 5171, 5177, 5181, 5391, 5392, 5411, 5481]
# Vertex 592:
# Faces: [936, 1950, 2006, 2961, 2985, 3067]
# Vertex 593:
# Faces: [1264, 1276, 1283, 1297, 1306]
# Vertex 594:
# Faces: [553, 1268, 1318, 1432, 1433]
# Vertex 595:
# Faces: [1560, 1577, 1617, 1697, 1873, 2031]
# Vertex 596:
# Faces: [738, 1219, 1707, 1708, 1833, 1837, 1897, 2043, 2046]
# Vertex 597:
# Faces: [353, 548, 604, 1236, 1254]
# Vertex 598:
# Faces: [1040, 1041, 1223, 1236, 1254, 1828]
# Vertex 599:
# Faces: [1363, 1497, 1499, 1539, 1946, 2023]
# Vertex 600:
# Faces: [1599, 1619, 1867, 1957, 1990]
# Vertex 601:
# Faces: [1732, 2010, 2917, 3264, 6514]
# Vertex 602:
# Faces: [1225, 1784, 2009, 2010, 2917, 3199, 6725]
# Vertex 603:
# Faces: [1352, 1397, 1529, 1559, 1586, 1647, 1891, 2241]
# Vertex 604:
# Faces: [1531, 2429, 2460, 2461, 4635]
# Vertex 605:
# Faces: [980, 1450, 1451, 2914, 2922, 2929, 2954]
# Vertex 606:
# Faces: [4343, 4345, 4389, 4415, 4416, 4417, 4418]
# Vertex 607:
# Faces: [1492, 1493, 1567, 1568, 2222]
# Vertex 608:
# Faces: [993, 1413, 1927, 1949, 2821, 5077]
# Vertex 609:
# Faces: [1321, 1322, 1426, 1454, 1722, 2022]
# Vertex 610:
# Faces: [1363, 1480, 1944, 1946, 1957, 1990]
# Vertex 611:
# Faces: [1333, 1397, 1559, 1583, 2059, 2063]
# Vertex 612:
# Faces: [1402, 1495, 1621, 1950, 2006]
# Vertex 613:
# Faces: [1830, 1843, 1844, 1860, 1861]
# Vertex 614:
# Faces: [1272, 1290, 1591, 1714, 2072]
# Vertex 615:
# Faces: [1458, 1470, 1471, 1515, 1691, 1725, 1728, 2024]
# Vertex 616:
# Faces: [1256, 1352, 1397, 1403, 1754, 2063]
# Vertex 617:
# Faces: [604, 1223, 1236, 1582, 1605, 1793, 2070]
# Vertex 618:
# Faces: [1428, 1469, 1582, 1675, 1793, 2042]
# Vertex 619:
# Faces: [1469, 1944, 1945, 1946, 1987, 2023, 2042]
# Vertex 620:
# Faces: [1966, 1967, 1999, 2000, 2012, 2013]
# Vertex 621:
# Faces: [1338, 1854, 1909, 1922, 2109, 2794, 3044, 4732]
# Vertex 622:
# Faces: [915, 1413, 1468, 1640, 2821]
# Vertex 623:
# Faces: [1814, 1829, 1830, 1831, 1859, 1860, 1898]
# Vertex 624:
# Faces: [284, 1605, 1674, 1794, 2070]
# Vertex 625:
# Faces: [1428, 1987, 2002, 2042]
# Vertex 626:
# Faces: [1259, 1361, 1517, 1646, 1823, 2029]
# Vertex 627:
# Faces: [1237, 1709, 1732, 1818, 3264]
# Vertex 628:
# Faces: [1441, 1442, 1472, 1489, 1490]
# Vertex 629:
# Faces: [1351, 1386, 1399, 1620, 1756, 1914, 1978]
# Vertex 630:
# Faces: [1844, 1861, 1887, 1899, 1900]
# Vertex 631:
# Faces: [1298, 1307, 1316, 1325, 1330, 1347]
# Vertex 632:
# Faces: [1855, 2000, 2001, 2013, 2033, 2053]
# Vertex 633:
# Faces: [474, 492, 1523, 1695, 1931, 1973]
# Vertex 634:
# Faces: [1238, 1467, 1945, 1976, 1987, 2002]
# Vertex 635:
# Faces: [1480, 1663, 1911, 1944, 1945, 1947, 1976]
# Vertex 636:
# Faces: [1480, 1599, 1600, 1663, 1990]
# Vertex 637:
# Faces: [1240, 1517, 1573, 1780, 1823, 1881]
# Vertex 638:
# Faces: [1225, 1228, 1229, 1334, 2009]
# Vertex 639:
# Faces: [1225, 1228, 1673, 1784, 2512, 2521, 2522]
# Vertex 640:
# Faces: [903, 2276, 2311, 2329, 4495, 4712, 4719]
# Vertex 641:
# Faces: [252, 292, 293, 1271, 1341, 2005]
# Vertex 642:
# Faces: [1218, 1401, 1525, 1558, 1693, 1764, 1771]
# Vertex 643:
# Faces: [1337, 1560, 1561, 1577, 1871, 1913]
# Vertex 644:
# Faces: [1899, 1900, 1919, 1920, 1935]
# Vertex 645:
# Faces: [2276, 2311, 4558]
# Vertex 646:
# Faces: [1338, 1647, 1854, 1891]
# Vertex 647:
# Faces: [1238, 1428, 1582, 1587, 1605, 1612, 1674, 2002]
# Vertex 648:
# Faces: [1259, 1361, 1599, 1600, 1867, 2049]
# Vertex 649:
# Faces: [282, 1209, 1237, 1241, 1818, 1904]
# Vertex 650:
# Faces: [1334, 1732, 1766, 1818, 1904, 2009, 2010]
# Vertex 651:
# Faces: [1228, 1229, 1230, 1453, 1673, 1731]
# Vertex 652:
# Faces: [89, 225, 469, 2436, 3476]
# Vertex 653:
# Faces: [1621, 1943, 2006, 2902, 2925, 2985]
# Vertex 654:
# Faces: [1642, 1885, 1886, 1934, 1980, 1997, 2428]
# Vertex 655:
# Faces: [1918, 1919, 1934, 1935, 1953, 1965, 1980, 1981]
# Vertex 656:
# Faces: [529, 1773, 1785, 1814, 1831]
# Vertex 657:
# Faces: [1246, 1600, 1663, 1911, 2049, 2065]
# Vertex 658:
# Faces: [819, 1573, 1796, 1838, 1881, 2359]
# Vertex 659:
# Faces: [1311, 1875, 2843, 2861, 2874]
# Vertex 660:
# Faces: [1391, 1405, 1429, 1459, 1487]
# Vertex 661:
# Faces: [6290, 6291, 6300, 6313, 6314, 6331, 6345, 6346]
# Vertex 662:
# Faces: [1219, 1272, 1591, 1897, 1968, 2052, 2067]
# Vertex 663:
# Faces: [1587, 1612, 1760, 1841, 2054]
# Vertex 664:
# Faces: [1335, 1467, 1513, 1514, 1947, 1976, 2061]
# Vertex 665:
# Faces: [1213, 1361, 1646, 1688, 2027, 2049, 2065]
# Vertex 666:
# Faces: [1517, 1573, 1646, 1838, 1853, 2027]
# Vertex 667:
# Faces: [1681, 1796, 1838, 1853, 1940]
# Vertex 668:
# Faces: [296, 332, 440, 818, 1616, 1786]
# Vertex 669:
# Faces: [1229, 1230, 1334, 1730, 1740, 1766, 1805]
# Vertex 670:
# Faces: [440, 1184, 1616, 1917, 2007, 3429]
# Vertex 671:
# Faces: [1098, 1256, 1333, 1353, 1425, 1482, 2063, 3218]
# Vertex 672:
# Faces: [751, 1638, 1653, 1683, 1852]
# Vertex 673:
# Faces: [1435, 1843, 1844, 1887, 1888, 1951]
# Vertex 674:
# Faces: [1353, 1377, 2235, 2236, 2301, 3218]
# Vertex 675:
# Faces: [1358, 1373, 1381, 1406, 1420, 1430]
# Vertex 676:
# Faces: [1406, 1419, 1430, 1443, 1460]
# Vertex 677:
# Faces: [1489, 1490, 1503, 1545, 1546, 1580, 1581, 1604]
# Vertex 678:
# Faces: [1006, 1042, 1587, 1674, 1794, 1993, 2054, 2819]
# Vertex 679:
# Faces: [1238, 1467, 1514, 1612, 1760]
# Vertex 680:
# Faces: [1246, 1723, 1878, 1911, 1947, 2061]
# Vertex 681:
# Faces: [1213, 1246, 1436, 1667, 1723, 2065]
# Vertex 682:
# Faces: [1213, 1436, 1557, 1688, 1907, 2030]
# Vertex 683:
# Faces: [1286, 1300, 1340, 1351, 1386, 1916]
# Vertex 684:
# Faces: [1304, 1305, 1343, 1344, 1356, 1357]
# Vertex 685:
# Faces: [263, 1553, 1755, 1893, 1964]
# Vertex 686:
# Faces: [1420, 1421, 1430, 1443, 1444, 1445]
# Vertex 687:
# Faces: [1664, 1681, 1688, 1802, 1853, 2027, 2030]
# Vertex 688:
# Faces: [141, 1453, 1731, 2513, 2523, 2536]
# Vertex 689:
# Faces: [1272, 2066, 2067, 2072]
# Vertex 690:
# Faces: [1277, 1284, 1293, 1294, 1298, 1307, 1308]
# Vertex 691:
# Faces: [213, 240, 241, 1216, 1269, 1742, 2517]
# Vertex 692:
# Faces: [1498, 1513, 1514, 1760, 1841, 2040, 2044]
# Vertex 693:
# Faces: [1667, 1668, 1692, 1723, 1878]
# Vertex 694:
# Faces: [1601, 1602, 1603, 1624, 1637, 1653, 1669, 1852]
# Vertex 695:
# Faces: [1214, 1846, 1855, 2012, 2013, 2051]
# Vertex 696:
# Faces: [2225, 2586, 3566, 6063]
# Vertex 697:
# Faces: [1216, 1742, 1811, 1993, 2056, 2819]
# Vertex 698:
# Faces: [1810, 1811, 1841, 1845, 1993, 2040, 2054]
# Vertex 699:
# Faces: [1456, 1556, 1711, 1845, 1858, 2040, 2044]
# Vertex 700:
# Faces: [1456, 1498, 1958, 1959, 1986, 2044]
# Vertex 701:
# Faces: [1335, 1498, 1513, 1958]
# Vertex 702:
# Faces: [1436, 1555, 1667, 1668, 1907, 1908]
# Vertex 703:
# Faces: [1557, 1802, 1808, 1817, 2030, 2045]
# Vertex 704:
# Faces: [1226, 1664, 1681, 1799, 1940, 5760]
# Vertex 705:
# Faces: [1369, 1370, 1394, 1417, 1418]
# Vertex 706:
# Faces: [141, 1230, 1453, 1494, 1740, 1989]
# Vertex 707:
# Faces: [1216, 1269, 1768, 2056]
# Vertex 708:
# Faces: [1335, 1692, 1698, 1878, 1958, 1959, 2061]
# Vertex 709:
# Faces: [1226, 1336, 1664, 1717, 1802, 1817, 1985]
# Vertex 710:
# Faces: [1330, 1346, 1347, 1358, 1371, 1381]
# Vertex 711:
# Faces: [1178, 1319, 1746, 2032, 2453, 2610, 3306]
# Vertex 712:
# Faces: [1319, 1730, 1740, 1989, 2453]
# Vertex 713:
# Faces: [242, 1294, 1308, 1317, 4036, 6226]
# Vertex 714:
# Faces: [167, 168, 1284, 1294, 4036]
# Vertex 715:
# Faces: [1922, 1923, 2588, 2794, 2948]
# Vertex 716:
# Faces: [1536, 1557, 1907, 1908, 2045]
# Vertex 717:
# Faces: [1494, 1511, 1989, 2032, 2453]
# Vertex 718:
# Faces: [1212, 1415, 1611, 1672, 1729]
# Vertex 719:
# Faces: [1920, 1935, 1936, 1953, 1966, 1967]
# Vertex 720:
# Faces: [1407, 1409, 1422, 1447, 1448]
# Vertex 721:
# Faces: [1768, 1810, 1811, 1876, 2056]
# Vertex 722:
# Faces: [1226, 1279, 1287, 1484, 1799, 1985]
# Vertex 723:
# Faces: [1425, 1458, 1465, 1471, 1482]
# Vertex 724:
# Faces: [48, 145, 163, 315, 2856]
# Vertex 725:
# Faces: [1359, 1374, 1395, 1423]
# Vertex 726:
# Faces: [1413, 1468, 1478, 1547, 1584, 1927, 2008]
# Vertex 727:
# Faces: [1458, 1465, 1470, 1983, 2427]
# Vertex 728:
# Faces: [1263, 1274, 1282, 1302, 1303]
# Vertex 729:
# Faces: [1655, 1810, 1842, 1845, 1858, 1876]
# Vertex 730:
# Faces: [1438, 1456, 1556, 1925, 1986]
# Vertex 731:
# Faces: [1247, 1387, 1698, 1895, 1925, 1959, 1960, 1986]
# Vertex 732:
# Faces: [1247, 1555, 1652, 1668, 1692, 1698, 1701]
# Vertex 733:
# Faces: [1576, 1620, 1733, 1901, 1978, 2048]
# Vertex 734:
# Faces: [1212, 1659, 1728, 1729, 2024]
# Vertex 735:
# Faces: [1263, 1274, 1275, 1510, 2953]
# Vertex 736:
# Faces: [1060, 1470, 1515, 1527, 1983, 2080]
# Vertex 737:
# Faces: [421, 1279, 1287, 1288, 4692]
# Vertex 738:
# Faces: [1837, 1893, 1897, 1964, 1968]
# Vertex 739:
# Faces: [1324, 1329, 1345, 1346, 1369, 1370, 1371]
# Vertex 740:
# Faces: [1508, 1708, 2043, 3009, 3442]
# Vertex 741:
# Faces: [858, 1508, 2778, 2944, 3442]
# Vertex 742:
# Faces: [1581, 1604, 1615, 1638, 1639, 1683, 1684]
# Vertex 743:
# Faces: [385, 458, 962, 2324, 2860]
# Vertex 744:
# Faces: [525, 1379, 1380, 1390, 1404]
# Vertex 745:
# Faces: [1262, 1479, 1655, 1696, 1842, 1882]
# Vertex 746:
# Faces: [1280, 1711, 1842, 1858, 1869, 1882]
# Vertex 747:
# Faces: [1536, 1590, 1632, 1808, 2045]
# Vertex 748:
# Faces: [1336, 1632, 1679, 1808, 1817, 1865]
# Vertex 749:
# Faces: [1287, 1288, 1289, 1717, 1985]
# Vertex 750:
# Faces: [1288, 1289, 1592, 1896, 2616, 2836, 4692]
# Vertex 751:
# Faces: [1337, 1576, 1913, 2048, 2057]
# Vertex 752:
# Faces: [1459, 1487, 1488, 1502, 1544, 1563]
# Vertex 753:
# Faces: [1360, 1659, 1660, 1725, 1728]
# Vertex 754:
# Faces: [993, 1848, 1949, 2071, 2779, 3790, 3804]
# Vertex 755:
# Faces: [942, 1690, 1848, 1923, 2779, 2948]
# Vertex 756:
# Faces: [1214, 1215, 1588, 1721, 1862, 2050, 2051]
# Vertex 757:
# Faces: [1313, 1314, 1328, 1366, 1367, 1379, 1380]
# Vertex 758:
# Faces: [1438, 1457, 1925, 1960, 1988]
# Vertex 759:
# Faces: [1247, 1634, 1636, 1652, 1895]
# Vertex 760:
# Faces: [1536, 1555, 1590, 1701, 1704, 1770, 1908]
# Vertex 761:
# Faces: [818, 1616, 1917, 2992, 3015]
# Vertex 762:
# Faces: [1098, 1465, 1482, 1863, 2427]
# Vertex 763:
# Faces: [1580, 1602, 1604, 1638, 1653]
# Vertex 764:
# Faces: [1248, 1280, 1323, 1696, 1839, 1882]
# Vertex 765:
# Faces: [1438, 1457, 1496, 1537, 1556, 1711, 1869]
# Vertex 766:
# Faces: [1387, 1427, 1578, 1634, 1895]
# Vertex 767:
# Faces: [1595, 1636, 1652, 1701, 1741, 1770]
# Vertex 768:
# Faces: [2069, 2157, 6020, 6251, 6684]
# Vertex 769:
# Faces: [314, 420, 458, 492, 962, 1523]
# Vertex 770:
# Faces: [61, 170, 245, 1055, 2665, 2825]
# Vertex 771:
# Faces: [1707, 1708, 1777, 2778, 3003, 3442]
# Vertex 772:
# Faces: [1322, 1576, 1733, 1767, 2022, 2057]
# Vertex 773:
# Faces: [1280, 1309, 1323, 1537, 1869]
# Vertex 774:
# Faces: [1427, 1634, 1636, 1735, 1741]
# Vertex 775:
# Faces: [1546, 1581, 1615, 2653]
# Vertex 776:
# Faces: [437, 505, 524, 1501, 1562, 1579]
# Vertex 777:
# Faces: [1337, 1849, 1871, 1901, 1961, 2048]
# Vertex 778:
# Faces: [1290, 1360, 1627, 1659, 1672, 1714, 1729, 1782]
# Vertex 779:
# Faces: [1393, 1394, 1417, 1441, 1442]
# Vertex 780:
# Faces: [510, 1222, 1309, 1323, 1839]
# Vertex 781:
# Faces: [510, 1309, 1496, 1537, 1737, 1955]
# Vertex 782:
# Faces: [1457, 1496, 1737, 1912, 1988, 2060]
# Vertex 783:
# Faces: [1387, 1578, 1912, 1960, 1988, 2041]
# Vertex 784:
# Faces: [1235, 1595, 1735, 1741, 1769, 1807, 1892]
# Vertex 785:
# Faces: [1595, 1704, 1705, 1770, 1807]
# Vertex 786:
# Faces: [1590, 1632, 1704, 1705, 1791, 1865]
# Vertex 787:
# Faces: [1592, 1594, 1779, 1896]
# Vertex 788:
# Faces: [3648, 3650, 3657, 3662, 3663]
# Vertex 789:
# Faces: [1860, 1861, 1898, 1899, 1918, 1919]
# Vertex 790:
# Faces: [621, 1743, 1744, 1785, 1812, 1813, 1814, 1829]
# Vertex 791:
# Faces: [1473, 1492, 1530, 1566, 1568]
# Vertex 792:
# Faces: [1383, 1455, 1585, 1658, 1712, 2313]
# Vertex 793:
# Faces: [1670, 1912, 2041, 2058, 2060]
# Vertex 794:
# Faces: [1427, 1464, 1578, 1613, 1735, 1892, 2041, 2058]
# Vertex 795:
# Faces: [1256, 1353, 1389, 1754, 2235]
# Vertex 796:
# Faces: [1219, 1970, 2014, 2015, 2034, 2046, 2052]
# Vertex 797:
# Faces: [529, 530, 568, 1830, 1831, 1843, 1951]
# Vertex 798:
# Faces: [1979, 2358, 2456, 2474, 6578]
# Vertex 799:
# Faces: [1748, 4574, 4584, 4663, 4664, 5794]
# Vertex 800:
# Faces: [160, 2497, 2529, 2670]
# Vertex 801:
# Faces: [1264, 1265, 1266, 1283, 1293, 1298, 1315, 1316]
# Vertex 802:
# Faces: [1248, 1255, 1262, 1574, 1696]
# Vertex 803:
# Faces: [1222, 1248, 1255, 1739, 1819, 1820, 1839]
# Vertex 804:
# Faces: [1462, 1593, 1670, 1677, 1737, 1955, 2060]
# Vertex 805:
# Faces: [1649, 1666, 1679, 1791, 1836, 1850, 1865, 1942]
# Vertex 806:
# Faces: [1289, 1336, 1592, 1594, 1608, 1679, 1717, 1942]
# Vertex 807:
# Faces: [2275, 2411, 4390, 4391, 4392, 4420]
# Vertex 808:
# Faces: [1214, 1215, 1360, 1660, 1782, 1846, 1890]
# Vertex 809:
# Faces: [61, 294, 1607, 2543, 2665, 4169]
# Vertex 810:
# Faces: [1296, 1454, 1572, 1722, 1759, 1877, 1929]
# Vertex 811:
# Faces: [1435, 1887, 1900, 1920, 1921, 1936]
# Vertex 812:
# Faces: [1283, 1297, 1315, 1324, 1329]
# Vertex 813:
# Faces: [1302, 1303, 1304, 1314, 1328, 1343]
# Vertex 814:
# Faces: [1464, 1481, 1593, 1651, 1670, 2058]
# Vertex 815:
# Faces: [1235, 1569, 1613, 1822, 1827, 1892]
# Vertex 816:
# Faces: [1400, 1705, 1769, 1791, 1807, 1850]
# Vertex 817:
# Faces: [1594, 1608, 1614, 1710, 1716, 1779, 2496]
# Vertex 818:
# Faces: [1544, 1563, 1564, 1565, 1601, 1603]
# Vertex 819:
# Faces: [589, 970, 983, 4423, 4424]
# Vertex 820:
# Faces: [1439, 1478, 1553, 1584, 1755]
# Vertex 821:
# Faces: [1491, 1503, 1530, 1546, 1566, 2653, 2687]
# Vertex 822:
# Faces: [1392, 1393, 1405, 1441, 1459, 1472, 1488]
# Vertex 823:
# Faces: [2311, 2329, 2507, 4537, 4558, 4872, 5214]
# Vertex 824:
# Faces: [1474, 1493, 1504, 2222, 2544]
# Vertex 825:
# Faces: [1444, 1445, 1446, 1473, 1474, 1492, 1493]
# Vertex 826:
# Faces: [260, 1023, 1024, 1211, 1255, 1382, 1574, 1739]
# Vertex 827:
# Faces: [1235, 1400, 1753, 1769, 1827]
# Vertex 828:
# Faces: [263, 1522, 1591, 1611, 1672, 1714, 1964, 1968]
# Vertex 829:
# Faces: [1281, 1282, 1292, 1302, 1313, 1314, 6327]
# Vertex 830:
# Faces: [1365, 1366, 1378, 1379, 1390, 1832]
# Vertex 831:
# Faces: [1290, 1627, 2033, 2053, 2066, 2072]
# Vertex 832:
# Faces: [1567, 2222, 2429, 2459, 2460, 2476, 2544]
# Vertex 833:
# Faces: [510, 1222, 1677, 1820, 1955]
# Vertex 834:
# Faces: [1606, 1618, 1753, 1822, 1824, 1827]
# Vertex 835:
# Faces: [1921, 1936, 1937, 1967, 1982, 2000, 2001]
# Vertex 836:
# Faces: [1322, 1399, 1426, 1733, 1978]
# Vertex 837:
# Faces: [1263, 1281, 1282, 1510, 1550, 6223]
# Vertex 838:
# Faces: [651, 652, 1435, 1719, 1888, 1921, 1937, 1991]
# Vertex 839:
# Faces: [1281, 1292, 6223, 6414, 6433]
# Vertex 840:
# Faces: [1862, 1965, 1981, 1998, 2050]
# Vertex 841:
# Faces: [1212, 1333, 1415, 1425, 1471, 1583, 2024]
# Vertex 842:
# Faces: [1109, 1110, 1575, 1825]
# Vertex 843:
# Faces: [1527, 1585, 1687, 2080, 2313, 5410]
# Vertex 844:
# Faces: [583, 654, 895, 1023, 1166, 1211, 1776]
# Vertex 845:
# Faces: [1211, 1217, 1273, 1382, 1776]
# Vertex 846:
# Faces: [1384, 1401, 1462, 1677, 1693, 1819, 1820, 2437]
# Vertex 847:
# Faces: [1464, 1481, 1541, 1569, 1613, 2062]
# Vertex 848:
# Faces: [1400, 1618, 1641, 1665, 1753, 1836, 1850]
# Vertex 849:
# Faces: [1608, 1614, 1666, 1806, 1942]
# Vertex 850:
# Faces: [1620, 1734, 1849, 1856, 1901, 1914]
# Vertex 851:
# Faces: [1321, 1575, 1767, 1825, 1872, 1948, 2022]
# Vertex 852:
# Faces: [1271, 1327, 1341, 1342, 2660, 6412]
# Vertex 853:
# Faces: [1356, 1357, 1368, 1391, 1392, 1405]
# Vertex 854:
# Faces: [1331, 1332, 1372, 1374, 1395, 1407, 1408, 1409]
# Vertex 855:
# Faces: [1848, 1909, 1922, 1923, 1926, 1927, 1949, 2008]
# Vertex 856:
# Faces: [2283, 2452, 3051, 3514, 4536, 4672]
# Vertex 857:
# Faces: [1311, 1321, 1722, 1875, 1929, 1948]
# Vertex 858:
# Faces: [1273, 1382, 1384, 1739, 1804, 1819]
# Vertex 859:
# Faces: [1296, 1877, 2438, 2497, 2670, 2787]
# Vertex 860:
# Faces: [1481, 1541, 1597, 1651]
# Vertex 861:
# Faces: [1569, 1606, 1822, 1941, 2062]
# Vertex 862:
# Faces: [1571, 1614, 1716, 1806, 1995, 2469]
# Vertex 863:
# Faces: [1328, 1343, 1356, 1367, 1368]
# Vertex 864:
# Faces: [1734, 1849, 1961, 2026]
# Vertex 865:
# Faces: [1545, 1565, 1580, 1602, 1603]
# Vertex 866:
# Faces: [1372, 1373, 1408, 1420, 1421]
# Vertex 867:
# Faces: [1338, 1586, 1891, 1909, 1926]
# Vertex 868:
# Faces: [1998, 1999, 2012, 2050, 2051]
# Vertex 869:
# Faces: [1618, 1641, 1756, 1824, 1856, 1914]
# Vertex 870:
# Faces: [1649, 1666, 1806, 1952, 1995]
# Vertex 871:
# Faces: [1386, 1399, 1426, 1454, 1572, 1916]
# Vertex 872:
# Faces: [156, 157, 187, 1264, 1265, 1275, 1276, 1956, 2953]
# Vertex 873:
# Faces: [1415, 1522, 1583, 1611, 2059]
# Vertex 874:
# Faces: [1627, 1782, 1846, 1855, 2053]
# Vertex 875:
# Faces: [1628, 1719, 1937, 1982, 2014, 2015]
# Vertex 876:
# Faces: [545, 936, 948, 1402, 1950]
# Vertex 877:
# Faces: [136, 137, 157, 1251, 1257, 1258, 1956]
# Vertex 878:
# Faces: [1417, 1418, 1419, 1442, 1460, 1490, 1491, 1503]
# Vertex 879:
# Faces: [1515, 1527, 1585, 1691, 1712]
# Vertex 880:
# Faces: [1313, 1327, 1342, 1365, 1366, 6327, 6432]
# Vertex 881:
# Faces: [1521, 1541, 1543, 1596, 1597, 1941, 2062]
# Vertex 882:
# Faces: [1340, 1351, 1641, 1665, 1756]
# Vertex 883:
# Faces: [1300, 1340, 1649, 1665, 1836, 1952]
# Vertex 884:
# Faces: [1383, 1660, 1691, 1712, 1725, 1890]
# Vertex 885:
# Faces: [231, 1039, 1291, 1388, 1561, 1577, 1697]
# Vertex 886:
# Faces: [1257, 1258, 1266, 1277, 1293]
# Vertex 887:
# Faces: [1859, 1886, 1898, 1918, 1934]
# Vertex 888:
# Faces: [62, 1449, 1450, 1451, 1505]
# Vertex 889:
# Faces: [123, 137, 139, 150, 1251]
# Vertex 890:
# Faces: [1341, 1342, 1365, 1378, 2005]
# Vertex 891:
# Faces: [1982, 2001, 2015, 2033, 2052, 2066, 2067]
# Vertex 892:
# Faces: [1315, 1316, 1329, 1330, 1346]
# Vertex 893:
# Faces: [1344, 1345, 1357, 1369, 1392, 1393, 1394]
# Vertex 894:
# Faces: [1933, 1938, 2160, 2328, 2371, 2373, 2419]
# Vertex 895:
# Faces: [1325, 1331, 1347, 1358, 1372, 1373]
# Vertex 896:
# Faces: [1443, 1444, 1460, 1473, 1491, 1530]
# Vertex 897:
# Faces: [193, 277, 352, 1657, 1686]
# Vertex 898:
# Faces: [1217, 1273, 1657, 1686, 1803, 1804]
# Vertex 899:
# Faces: [1384, 1401, 1771, 1803, 1804]
# Vertex 900:
# ...
# [3179, 3228, 3269, 3270, 3300, 3318]
# Vertex adjacent to vertex 3254:
# [3231, 3240, 3255, 3274, 3283, 3284, 3285]
# Vertex adjacent to vertex 3255:
# [3215, 3216, 3231, 3254, 3274, 3275]
# Vertex adjacent to vertex 3256:
# [3216, 3217, 3241, 3275, 3276, 3287]
# Vertex adjacent to vertex 3257:
# [186, 241, 249, 2668, 3053, 3393]
# Vertex adjacent to vertex 3258:
# [1861, 1881, 1891, 3220, 3249, 3310, 3311]
# Vertex adjacent to vertex 3259:
# [3220, 3233, 3249, 3293, 3312]
# Vertex adjacent to vertex 3260:
# [1091, 3232, 3246, 3451, 3465, 3470]
# Vertex adjacent to vertex 3261:
# [3222, 3250, 3251, 3295, 3296, 3315, 3371, 3372]
# Vertex adjacent to vertex 3262:
# [3223, 3251, 3263, 3296, 3297, 3333, 3345]
# Vertex adjacent to vertex 3263:
# [3223, 3224, 3225, 3262, 3264, 3297]
# Vertex adjacent to vertex 3264:
# [3225, 3263, 3265, 3297]
# Vertex adjacent to vertex 3265:
# [3203, 3204, 3225, 3226, 3264, 3280, 3297]
# Vertex adjacent to vertex 3266:
# [3207, 3227, 3252, 3267, 3268, 3281, 3298]
# Vertex adjacent to vertex 3267:
# [3207, 3208, 3266, 3268]
# Vertex adjacent to vertex 3268:
# [3208, 3228, 3266, 3267, 3269, 3281, 3299]
# Vertex adjacent to vertex 3269:
# [3228, 3253, 3268, 3299, 3318]
# Vertex adjacent to vertex 3270:
# [3179, 3209, 3235, 3253, 3271, 3300]
# Vertex adjacent to vertex 3271:
# [3235, 3236, 3270, 3300, 3301, 3319]
# Vertex adjacent to vertex 3272:
# [3229, 3237, 3238, 3273, 3282, 3283, 3302, 3319, 3335]
# Vertex adjacent to vertex 3273:
# [3272, 3282, 3283, 3321]
# Vertex adjacent to vertex 3274:
# [3254, 3255, 3275, 3285, 3286, 3304]
# Vertex adjacent to vertex 3275:
# [3216, 3255, 3256, 3274, 3286, 3287]
# Vertex adjacent to vertex 3276:
# [564, 3241, 3242, 3256, 3287]
# Vertex adjacent to vertex 3277:
# [499, 1649, 3147, 3245, 3290, 3339, 3385]
# Vertex adjacent to vertex 3278:
# [839, 2242, 3184, 3243, 3289, 3306, 3361]
# Vertex adjacent to vertex 3279:
# [1131, 1627, 3185, 3201, 3327, 3376, 3386]
# Vertex adjacent to vertex 3280:
# [3226, 3252, 3265, 3297, 3298, 3316, 3346]
# Vertex adjacent to vertex 3281:
# [3266, 3268, 3298, 3299, 3317, 3356, 3357]
# Vertex adjacent to vertex 3282:
# [3272, 3273, 3302, 3303, 3321, 3348]
# Vertex adjacent to vertex 3283:
# [3238, 3239, 3240, 3254, 3272, 3273, 3284, 3321]
# Vertex adjacent to vertex 3284:
# [3254, 3283, 3285, 3321, 3322, 3338]
# Vertex adjacent to vertex 3285:
# [3254, 3274, 3284, 3304, 3322, 3323]
# Vertex adjacent to vertex 3286:
# [3274, 3275, 3287, 3304, 3305]
# Vertex adjacent to vertex 3287:
# [564, 3256, 3275, 3276, 3286, 3305]
# Vertex adjacent to vertex 3288:
# [1539, 2406, 3219, 3248, 3340, 3383, 3384]
# Vertex adjacent to vertex 3289:
# [2242, 3243, 3278, 3308, 3309]
# Vertex adjacent to vertex 3290:
# [1631, 1649, 3245, 3277, 3307]
# Vertex adjacent to vertex 3291:
# [1249, 3185, 3202, 3328, 3381]
# Vertex adjacent to vertex 3292:
# [1891, 1892, 3310, 3329, 3330]
# Vertex adjacent to vertex 3293:
# [1832, 1833, 3233, 3259, 3294, 3312, 3332, 3341]
# Vertex adjacent to vertex 3294:
# [1833, 3293, 3313, 3332, 3354, 3369]
# Vertex adjacent to vertex 3295:
# [1455, 1456, 3222, 3234, 3261, 3315, 3343]
# Vertex adjacent to vertex 3296:
# [3251, 3261, 3262, 3345, 3372, 3392]
# Vertex adjacent to vertex 3297:
# [3262, 3263, 3264, 3265, 3280, 3333, 3346]
# Vertex adjacent to vertex 3298:
# [3252, 3266, 3280, 3281, 3316, 3356]
# Vertex adjacent to vertex 3299:
# [3268, 3269, 3281, 3317, 3318, 3334]
# Vertex adjacent to vertex 3300:
# [3253, 3270, 3271, 3318, 3319, 3334, 3335]
# Vertex adjacent to vertex 3301:
# [3236, 3237, 3271, 3319]
# Vertex adjacent to vertex 3302:
# [3272, 3282, 3303, 3320, 3335, 3348]
# Vertex adjacent to vertex 3303:
# [3282, 3302, 3348]
# Vertex adjacent to vertex 3304:
# [3274, 3285, 3286, 3305, 3323, 3324]
# Vertex adjacent to vertex 3305:
# [31, 564, 569, 3286, 3287, 3304, 3324]
# Vertex adjacent to vertex 3306:
# [521, 852, 880, 3184, 3247, 3278, 3361]
# Vertex adjacent to vertex 3307:
# [1159, 1578, 1607, 1631, 3245, 3290]
# Vertex adjacent to vertex 3308:
# [1648, 1673, 3243, 3289, 3309, 3325]
# Vertex adjacent to vertex 3309:
# [403, 437, 1648, 2242, 3289, 3308]
# Vertex adjacent to vertex 3310:
# [1891, 3258, 3292, 3311, 3330, 3331]
# Vertex adjacent to vertex 3311:
# [3249, 3258, 3310, 3312, 3331]
# Vertex adjacent to vertex 3312:
# [3249, 3259, 3293, 3311, 3331, 3341]
# Vertex adjacent to vertex 3313:
# [1826, 1833, 3294, 3342, 3369]
# Vertex adjacent to vertex 3314:
# [1465, 3315, 3343, 3344]
# Vertex adjacent to vertex 3315:
# [3261, 3295, 3314, 3343, 3344, 3371]
# Vertex adjacent to vertex 3316:
# [1459, 3280, 3298, 3346, 3355, 3356, 3377]
# Vertex adjacent to vertex 3317:
# [3281, 3299, 3334, 3357]
# Vertex adjacent to vertex 3318:
# [3253, 3269, 3299, 3300, 3334]
# Vertex adjacent to vertex 3319:
# [3237, 3271, 3272, 3300, 3301, 3335]
# Vertex adjacent to vertex 3320:
# [3302, 3335, 3336, 3347, 3348]
# Vertex adjacent to vertex 3321:
# [3273, 3282, 3283, 3284, 3337, 3338, 3348]
# Vertex adjacent to vertex 3322:
# [559, 568, 3284, 3285, 3323, 3338, 3351]
# Vertex adjacent to vertex 3323:
# [559, 3285, 3304, 3322, 3324]
# Vertex adjacent to vertex 3324:
# [25, 31, 559, 3304, 3305, 3323]
# Vertex adjacent to vertex 3325:
# [1673, 2990, 3243, 3308, 3376]
# Vertex adjacent to vertex 3326:
# [550, 1249, 1394, 1781, 3096, 3202]
# Vertex adjacent to vertex 3327:
# [1131, 3147, 3201, 3279, 3362, 3385]
# Vertex adjacent to vertex 3328:
# [3147, 3185, 3201, 3291, 3381]
# Vertex adjacent to vertex 3329:
# [1892, 1912, 1926, 3292, 3330, 3366, 3388]
# Vertex adjacent to vertex 3330:
# [3292, 3310, 3329, 3331, 3366]
# Vertex adjacent to vertex 3331:
# [3310, 3311, 3312, 3330, 3341, 3366, 3367, 3368]
# Vertex adjacent to vertex 3332:
# [1173, 2807, 2847, 3293, 3294, 3341, 3354, 3368]
# Vertex adjacent to vertex 3333:
# [3262, 3297, 3345, 3346, 3373, 3374]
# Vertex adjacent to vertex 3334:
# [3299, 3300, 3317, 3318, 3335, 3336, 3357, 3378]
# Vertex adjacent to vertex 3335:
# [3272, 3300, 3302, 3319, 3320, 3334, 3336]
# Vertex adjacent to vertex 3336:
# [3320, 3334, 3335, 3347, 3378, 3397]
# Vertex adjacent to vertex 3337:
# [3321, 3338, 3348, 3349, 3350]
# Vertex adjacent to vertex 3338:
# [3284, 3321, 3322, 3337, 3350, 3351]
# Vertex adjacent to vertex 3339:
# [499, 3184, 3187, 3247, 3277, 3362, 3385]
# Vertex adjacent to vertex 3340:
# [768, 1468, 1945, 1946, 1986, 3146, 3219, 3288, 3384]
# Vertex adjacent to vertex 3341:
# [3293, 3312, 3331, 3332, 3368]
# Vertex adjacent to vertex 3342:
# [1601, 1826, 3313, 3369]
# Vertex adjacent to vertex 3343:
# [1456, 1457, 1464, 1465, 3295, 3314, 3315]
# Vertex adjacent to vertex 3344:
# [1465, 3314, 3315, 3370, 3371]
# Vertex adjacent to vertex 3345:
# [3262, 3296, 3333, 3373, 3392]
# Vertex adjacent to vertex 3346:
# [3280, 3297, 3316, 3333, 3355, 3374, 3375]
# Vertex adjacent to vertex 3347:
# [3320, 3336, 3348, 3358, 3397, 3398]
# Vertex adjacent to vertex 3348:
# [3282, 3302, 3303, 3320, 3321, 3337, 3347, 3349, 3358]
# Vertex adjacent to vertex 3349:
# [3337, 3348, 3350, 3358, 3379, 3380]
# Vertex adjacent to vertex 3350:
# [563, 3337, 3338, 3349, 3351, 3380]
# Vertex adjacent to vertex 3351:
# [563, 568, 3322, 3338, 3350]
# Vertex adjacent to vertex 3352:
# [1635, 2777, 3053, 3171, 3244, 3382, 3393]
# Vertex adjacent to vertex 3353:
# [1031, 1056, 2406, 2807, 2847, 3383, 3394]
# Vertex adjacent to vertex 3354:
# [2807, 3294, 3332, 3369, 3389]
# Vertex adjacent to vertex 3355:
# [1459, 1469, 3316, 3346, 3375]
# Vertex adjacent to vertex 3356:
# [3281, 3298, 3316, 3357, 3377, 3396]
# Vertex adjacent to vertex 3357:
# [3281, 3317, 3334, 3356, 3378, 3396]
# Vertex adjacent to vertex 3358:
# [1171, 3347, 3348, 3349, 3379, 3398]
# Vertex adjacent to vertex 3359:
# [260, 328, 338, 1600, 2620, 2668]
# Vertex adjacent to vertex 3360:
# [1584, 1627, 1633, 1667, 1674, 3376]
# Vertex adjacent to vertex 3361:
# [829, 839, 880, 3278, 3306]
# Vertex adjacent to vertex 3362:
# [1131, 2990, 3184, 3243, 3327, 3339, 3385]
# Vertex adjacent to vertex 3363:
# [1926, 1932, 1942, 1943, 1955, 1973, 3364]
# Vertex adjacent to vertex 3364:
# [1926, 1943, 3363, 3387, 3388]
# Vertex adjacent to vertex 3365:
# [171, 452, 1616, 1625, 3171, 3172]
# Vertex adjacent to vertex 3366:
# [661, 2466, 3329, 3330, 3331, 3367, 3388]
# Vertex adjacent to vertex 3367:
# [661, 3331, 3366, 3368]
# Vertex adjacent to vertex 3368:
# [661, 1173, 3331, 3332, 3341, 3367]
# Vertex adjacent to vertex 3369:
# [1561, 1601, 3294, 3313, 3342, 3354, 3389, 3390]
# Vertex adjacent to vertex 3370:
# [1458, 1465, 1466, 3344, 3371, 3372, 3391]
# Vertex adjacent to vertex 3371:
# [3261, 3315, 3344, 3370, 3372]
# Vertex adjacent to vertex 3372:
# [3261, 3296, 3370, 3371, 3391, 3392]
# Vertex adjacent to vertex 3373:
# [562, 3333, 3345, 3374, 3392]
# Vertex adjacent to vertex 3374:
# [562, 3333, 3346, 3373, 3375]
# Vertex adjacent to vertex 3375:
# [562, 572, 573, 1469, 3346, 3355, 3374]
# Vertex adjacent to vertex 3376:
# [1131, 1627, 1667, 1673, 2990, 3279, 3325, 3360]
# Vertex adjacent to vertex 3377:
# [1459, 1470, 3316, 3356, 3395, 3396]
# Vertex adjacent to vertex 3378:
# [1042, 2431, 3334, 3336, 3357, 3396, 3397]
# Vertex adjacent to vertex 3379:
# [1171, 3349, 3358, 3380]
# Vertex adjacent to vertex 3380:
# [563, 574, 575, 576, 1171, 3349, 3350, 3379]
# Vertex adjacent to vertex 3381:
# [1249, 1607, 3147, 3245, 3291, 3328]
# Vertex adjacent to vertex 3382:
# [231, 232, 249, 3053, 3244, 3352]
# Vertex adjacent to vertex 3383:
# [1031, 1539, 2406, 2620, 3288, 3353]
# Vertex adjacent to vertex 3384:
# [661, 1946, 2406, 2671, 2683, 3136, 3288, 3340]
# Vertex adjacent to vertex 3385:
# [3147, 3277, 3327, 3339, 3362]
# Vertex adjacent to vertex 3386:
# [1305, 1343, 1627, 3185, 3186, 3279]
# Vertex adjacent to vertex 3387:
# [1927, 1943, 2466, 2671, 3364, 3388]
# Vertex adjacent to vertex 3388:
# [1926, 2466, 3329, 3364, 3366, 3387]
# Vertex adjacent to vertex 3389:
# [1056, 1624, 2807, 3354, 3369, 3390]
# Vertex adjacent to vertex 3390:
# [1561, 1614, 1624, 3369, 3389]
# Vertex adjacent to vertex 3391:
# [1144, 1466, 3370, 3372, 3392]
# Vertex adjacent to vertex 3392:
# [562, 1144, 2462, 3296, 3345, 3372, 3373, 3391]
# Vertex adjacent to vertex 3393:
# [186, 452, 3053, 3171, 3199, 3257, 3352]
# Vertex adjacent to vertex 3394:
# [1173, 2406, 2847, 3136, 3353]
# Vertex adjacent to vertex 3395:
# [1470, 1471, 2431, 3377, 3396]
# Vertex adjacent to vertex 3396:
# [2431, 3356, 3357, 3377, 3378, 3395]
# Vertex adjacent to vertex 3397:
# [1042, 1474, 2684, 3336, 3347, 3378, 3398]
# Vertex adjacent to vertex 3398:
# [978, 1171, 2684, 3347, 3358, 3397]
# Vertex adjacent to vertex 3399:
# [3401, 3429, 3432, 3454, 3456, 3466, 3473]
# Vertex adjacent to vertex 3400:
# [1676, 2228, 2276, 2601, 3453]
# Vertex adjacent to vertex 3401:
# [102, 736, 843, 989, 3399, 3406, 3466, 3473]
# Vertex adjacent to vertex 3402:
# [2726, 3419, 3423, 3447, 3479]
# Vertex adjacent to vertex 3403:
# [2386, 2628, 2632, 2712, 2724, 2852, 3432, 3477]
# Vertex adjacent to vertex 3404:
# [2725, 2741, 2816, 3461, 3472, 3478]
# Vertex adjacent to vertex 3405:
# [1653, 3420, 3472, 3484]
# Vertex adjacent to vertex 3406:
# [674, 989, 1141, 3401, 3407, 3466]
# Vertex adjacent to vertex 3407:
# [447, 1141, 3406, 3457, 3466]
# Vertex adjacent to vertex 3408:
# [3415, 3418, 3427, 3434, 3435, 3451]
# Vertex adjacent to vertex 3409:
# [447, 2463, 2797, 3413, 3416, 3442, 3457]
# Vertex adjacent to vertex 3410:
# [1866, 2702, 2815, 3417, 3422, 3425]
# Vertex adjacent to vertex 3411:
# [999, 1018, 1083, 3418, 3427, 3459, 3480]
# Vertex adjacent to vertex 3412:
# [2386, 2553, 2629, 3438, 3477, 3484]
# Vertex adjacent to vertex 3413:
# [447, 968, 976, 1115, 3409, 3442]
# Vertex adjacent to vertex 3414:
# [1933, 3200, 3415, 3435, 3445, 3467]
# Vertex adjacent to vertex 3415:
# [3408, 3414, 3434, 3435, 3449, 3467]
# Vertex adjacent to vertex 3416:
# [1010, 1093, 2463, 2486, 3409, 3437, 3442]
# Vertex adjacent to vertex 3417:
# [696, 1009, 1866, 2127, 3410, 3422]
# Vertex adjacent to vertex 3418:
# [3408, 3411, 3427, 3434, 3459]
# Vertex adjacent to vertex 3419:
# [3402, 3423, 3430, 3452, 3479, 3483]
# Vertex adjacent to vertex 3420:
# [3405, 3450, 3471, 3472, 3478, 3484]
# Vertex adjacent to vertex 3421:
# [3439, 3448, 3458, 3463, 3481]
# Vertex adjacent to vertex 3422:
# [696, 1046, 1134, 3410, 3417, 3425, 3469]
# Vertex adjacent to vertex 3423:
# [3402, 3419, 3447, 3452, 3455]
# Vertex adjacent to vertex 3424:
# [987, 2510, 3425, 3433, 3446, 3469]
# Vertex adjacent to vertex 3425:
# [2510, 2702, 3410, 3422, 3424, 3469]
# Vertex adjacent to vertex 3426:
# [5, 856, 1113, 3454]
# Vertex adjacent to vertex 3427:
# [3408, 3411, 3418, 3451, 3470, 3476, 3480]
# Vertex adjacent to vertex 3428:
# [1869, 2628, 2712, 3456, 3457, 3466]
# Vertex adjacent to vertex 3429:
# [856, 3399, 3432, 3454, 3464, 3477]
# Vertex adjacent to vertex 3430:
# [1024, 3419, 3452, 3465, 3475, 3483]
# Vertex adjacent to vertex 3431:
# [1302, 1976, 3443, 3445, 3467]
# Vertex adjacent to vertex 3432:
# [2712, 3399, 3403, 3429, 3456, 3477]
# Vertex adjacent to vertex 3433:
# [987, 3424, 3446, 3447, 3455]
# Vertex adjacent to vertex 3434:
# [3408, 3415, 3418, 3449, 3459, 3468]
# Vertex adjacent to vertex 3435:
# [3200, 3232, 3408, 3414, 3415, 3451]
# Vertex adjacent to vertex 3436:
# [2510, 2726, 2766, 3446, 3447]
# Vertex adjacent to vertex 3437:
# [962, 1093, 2486, 2656, 3416]
# Vertex adjacent to vertex 3438:
# [3412, 3464, 3471, 3477, 3484]
# Vertex adjacent to vertex 3439:
# [1178, 1805, 3421, 3443, 3458, 3481]
# Vertex adjacent to vertex 3440:
# [160, 226, 2172, 2217, 3453, 3462]
# Vertex adjacent to vertex 3441:
# [798, 998, 1098, 1161, 1188, 3461, 3478]
# Vertex adjacent to vertex 3442:
# [976, 995, 1010, 3409, 3413, 3416]
# Vertex adjacent to vertex 3443:
# [1154, 1805, 1976, 3431, 3439, 3467, 3481]
# Vertex adjacent to vertex 3444:
# [856, 971, 1113, 1143, 3450, 3464, 3471]
# Vertex adjacent to vertex 3445:
# [1302, 1342, 1933, 3414, 3431, 3467]
# Vertex adjacent to vertex 3446:
# [2510, 3424, 3433, 3436, 3447]
# Vertex adjacent to vertex 3447:
# [2726, 3402, 3423, 3433, 3436, 3446, 3455]
# Vertex adjacent to vertex 3448:
# [3421, 3458, 3460, 3462, 3463]
# Vertex adjacent to vertex 3449:
# [3415, 3434, 3467, 3468, 3481]
# Vertex adjacent to vertex 3450:
# [998, 1143, 3420, 3444, 3471, 3478]
# Vertex adjacent to vertex 3451:
# [3232, 3260, 3408, 3427, 3435, 3470]
# Vertex adjacent to vertex 3452:
# [1024, 1129, 3419, 3423, 3430, 3455]
# Vertex adjacent to vertex 3453:
# [1676, 2217, 2228, 3400, 3440, 3460, 3462]
# Vertex adjacent to vertex 3454:
# [5, 856, 3399, 3426, 3429, 3473, 3482]
# Vertex adjacent to vertex 3455:
# [987, 1048, 1129, 3423, 3433, 3447, 3452]
# Vertex adjacent to vertex 3456:
# [2712, 3399, 3428, 3432, 3466]
# Vertex adjacent to vertex 3457:
# [447, 1869, 2797, 3407, 3409, 3428, 3466]
# Vertex adjacent to vertex 3458:
# [1178, 3421, 3439, 3448, 3460]
# Vertex adjacent to vertex 3459:
# [1083, 1099, 1160, 3411, 3418, 3434, 3468, 3474]
# Vertex adjacent to vertex 3460:
# [1178, 1676, 2661, 3448, 3453, 3458, 3462]
# Vertex adjacent to vertex 3461:
# [949, 1188, 1189, 2725, 3404, 3441, 3478]
# Vertex adjacent to vertex 3462:
# [226, 3440, 3448, 3453, 3460, 3463]
# Vertex adjacent to vertex 3463:
# [226, 1012, 3421, 3448, 3462, 3474, 3481]
# Vertex adjacent to vertex 3464:
# [856, 3429, 3438, 3444, 3471, 3477]
# Vertex adjacent to vertex 3465:
# [1780, 3246, 3260, 3430, 3470, 3475, 3483]
# Vertex adjacent to vertex 3466:
# [3399, 3401, 3406, 3407, 3428, 3456, 3457]
# Vertex adjacent to vertex 3467:
# [3414, 3415, 3431, 3443, 3445, 3449, 3481]
# Vertex adjacent to vertex 3468:
# [3434, 3449, 3459, 3474, 3481]
# Vertex adjacent to vertex 3469:
# [987, 1134, 3422, 3424, 3425]
# Vertex adjacent to vertex 3470:
# [3260, 3427, 3451, 3465, 3475, 3476]
# Vertex adjacent to vertex 3471:
# [3420, 3438, 3444, 3450, 3464, 3484]
# Vertex adjacent to vertex 3472:
# [1653, 2741, 3404, 3405, 3420, 3478]
# Vertex adjacent to vertex 3473:
# [843, 3399, 3401, 3454, 3482]
# Vertex adjacent to vertex 3474:
# [1012, 1160, 3459, 3463, 3468, 3481]
# Vertex adjacent to vertex 3475:
# [1024, 3430, 3465, 3470, 3476]
# Vertex adjacent to vertex 3476:
# [1024, 3427, 3470, 3475, 3480]
# Vertex adjacent to vertex 3477:
# [2386, 3403, 3412, 3429, 3432, 3438, 3464]
# Vertex adjacent to vertex 3478:
# [998, 3404, 3420, 3441, 3450, 3461, 3472]
# Vertex adjacent to vertex 3479:
# [1844, 1949, 2726, 3402, 3419, 3483]
# Vertex adjacent to vertex 3480:
# [999, 1024, 1199, 3411, 3427, 3476]
# Vertex adjacent to vertex 3481:
# [3421, 3439, 3443, 3449, 3463, 3467, 3468, 3474]
# Vertex adjacent to vertex 3482:
# [5, 792, 843, 3454, 3473]
# Vertex adjacent to vertex 3483:
# [1780, 1811, 1844, 3419, 3430, 3465, 3479]
# Vertex adjacent to vertex 3484:
# [1653, 2629, 3405, 3412, 3420, 3438, 3471]

# %% [markdown]
# ## Shading
#
# Meshplot requires per vertex normals, so we need to "explode" the mesh

# %%
def explode(V, F):
    e_v = np.copy([V[0]])
    e_f = np.copy(F)

    # checked = []
    vertex = 0
    
    index_i = 0
    for i in F:
        index_j = 0
        
        for j in i:            
            e_f[index_i][index_j] = vertex
            if vertex == 0: 
                index_j += 1
                vertex +=1
                continue
            
            index_j += 1
            vertex += 1
            e_v = np.append(e_v, [np.copy(V[j])], axis=0)
        index_i += 1
    
    return e_v, e_f

v, f = explode(cube_v, cube_f)

# %% [markdown]
# ### Flat Shading

# %%
def flat(V, F):
    Z = np.zeros(3)
    return igl.per_face_normals(V, F, Z)

v = sphere_v
f = sphere_f
n = flat(v, f)
meshplot.plot(v, f, n=n, shading={"flat": True})
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.0, 0.0,…

# %% [markdown]
# ### Per-vertex Shading

# %%
def vertex(V, F):
    return igl.per_vertex_normals(V, F)

v = sphere_v
f = sphere_f
n = vertex(v, f)
meshplot.plot(v, f, n=n, shading={"flat": False})
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.0, 0.0,…

# %% [markdown]
# ### Per-corner Shading

# %%
def corner(V, F):
    e_v, e_f = explode(V, F)
    N = igl.per_corner_normals(V, F, 20.)
    return N, e_v, e_f

v = bunny_v
f = bunny_f
n, v, f = corner(v, f)
meshplot.plot(v, f, n=n, shading={"flat": False})
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-0.016860…

# %% [markdown]
# ## Connected Components

# %%
def con_com(F):
    cc = igl.face_components(F)
    print(np.unique(cc).size)
    meshplot.plot(v, f, c=cc)
    return

v, f = igl.read_triangle_mesh("data/car.off")
con_com(f)

v, f = igl.read_triangle_mesh("data/coffeecup.off")
con_com(f)
# Out:
# 11
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-7.194198…
# 2
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-3.253649…

# %% [markdown]
# ## A simple subdivision scheme

# %%
import math

def subdivision(V, F):
    # step 1
    vn = V.shape[0]
    M = igl.barycenter(V, F)
    new_v = np.append(V, M, axis=0)

    index = 0
    new_face = np.empty((1,3))
    for face in F:
        a, b, c = face
        new_face = np.append(new_face, [[a, b, vn + index]], axis = 0)
        new_face = np.append(new_face, [[c, b, vn + index]], axis = 0)
        new_face = np.append(new_face, [[a, c, vn + index]], axis = 0)
        index += 1
        
    # step 2
    p = V.copy()
    l = igl.adjacency_list(F)
    index = 0
    for x in l:
        n = len(x)
        a = (4 - 2 * math.cos(2 * math.pi / n)) / 9
        v = V[index]
        
        vi = np.sum(V[x], axis = 0)
        p[index] = (1-a)*v + (a/n)*vi
        
        nv = np.vstack((p, M))
        index += 1

    #step 3
    t, to = igl.triangle_triangle_adjacency(F)    
    index = 0
    nf = np.empty((1,3))
    for face in F:
        t0 = t[index][0]
        t1 = t[index][1]
        t2 = t[index][2]

        for tri in t[index]:
            for ver in F[tri]:
                if ver in face:
                    nf = np.append(nf, [[ver, vn+index, tri+vn]], axis=0)
        
        index+=1
    return nv, nf

v, f = igl.read_triangle_mesh("data/sphere.obj")
v, f = subdivision(v, f)
meshplot.plot(v, f, shading={"wireframe": True})

v, f = igl.read_triangle_mesh("data/bumpy.off")
v, f = subdivision(v, f)
meshplot.plot(v, f, shading={"wireframe": True})
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(2.9802322…
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.0, 0.0,…

# %% [markdown]
# V = cube_v.copy()
# F = cube_f.copy()
#
# M = igl.barycenter()
# v_pp = np.row_stack((V, M))
#
# ev, fe, ef = igl.edge_topology(v, f)
#
# offset = V.shape[0]
# f_pp = []
#
# for fi, es in enumerate(fe):
#     m_fi_i = fi + offset
#
#     for ei in es:
#         e = ev[ei]
#         f_pp.append([e[0], e[1], m_fi_i])
#
# f_pp = np.array(f_pp)
#
# v_p = v_pp.copy()
# vv = igl.adjacency_list(F)
#
# for i in range(V.shape[0]):
#     neighs = vv[i]
#     n = len(neighs)
#     an = (4-2 * cos(2*pi/n)) / 9
#     p = (1-an) * V[i]
#     for j in neighs:
#         p+=an/n*V[j]
#
# ev, fe, ef = igl.edge_topology(F-pp)
#
# for ei, e in enumerate(ev):
#     if e[0] >= V.shape[0] or e[1] >= V.shape[0]:
#         continue
#
#     f0 = ef[ei, 0]
#     f1 = ef[ei, 1]
#
#     vf0 = f_pp[f0]
#     vf1 = f_pp[f1]
#
#     vf0s = set(vf0)
#     vf1s = set(vf1)
#
#     es = set(e)
#     Ls = vf0s - es
#     Rs = vf1s - es
#
#     L = Ls.pop()
#     R = Rs.pop()
#
#     f_p[f0] = [e[0], R, L]
#     f_p[f1] = [e[1], R, L]
